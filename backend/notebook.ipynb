# %%
import pandas as pd
import numpy as np
import seaborn as sns

csv = pd.read_csv("data2.csv")
df = pd.DataFrame(csv)
df_time_offset = df["Timestamp"][0]
df["Timestamp"] = df["Timestamp"] - df_time_offset
df
# Out:
#     Timestamp       a_x       a_y       a_z       g_x       g_y       g_z  \
# 0    0.000000  0.002381 -0.002319 -1.012824  0.067100 -0.087543 -0.012928
# 1    0.010010  0.002264 -0.001322 -1.010777 -0.027431  0.053711  0.007238
# 2    0.019958 -0.006437  0.000734 -0.996324 -0.098246  0.001828 -0.008438
# 3    0.029968 -0.006653 -0.000221 -1.010354 -0.062689  0.001936 -0.008764
# 4    0.039978 -0.000071  0.000970 -1.003384  0.132711  0.072633 -0.012128
# 5    0.049988 -0.006115  0.001930 -0.998875  0.079416  0.054945 -0.011246
# 6    0.059998 -0.002156  0.000353 -1.007763  0.008602  0.003062 -0.026922
# 7    0.070007 -0.001435  0.000173 -0.998847  0.061937  0.003224 -0.027411
# 8    0.079956 -0.001090 -0.000578 -1.008821  0.043628  0.000440  0.025276
# 9    0.089966 -0.003650  0.002184 -0.998432 -0.045346  0.035221  0.025303
# 10   0.099976 -0.003614  0.001922 -1.006627 -0.009748  0.017804  0.025371
# 11   0.109985 -0.003934  0.001718 -1.003347 -0.026683  0.039825 -0.062400
# 12   0.119995 -0.001936  0.000504 -1.002218  0.008602  0.003062 -0.026923
# 13   0.130005 -0.001489 -0.001293 -1.002147  0.079933 -0.013338 -0.044688
# 14   0.139954 -0.002375 -0.001570 -1.001641 -0.152234  0.051513  0.043394
# 15   0.149963 -0.003029 -0.000256 -1.003736  0.043628  0.000440  0.025276
# 16   0.159973 -0.003869 -0.000196 -0.999689 -0.133585 -0.014896 -0.025227
# 17   0.169983 -0.003798  0.001769 -1.006510  0.026380  0.003116 -0.027085
# 18   0.179993 -0.002608  0.000680 -1.001607 -0.009340  0.073111 -0.028334
# 19   0.190002 -0.001400 -0.001035 -1.001226 -0.028098  0.032546  0.077664
# 20   0.200012 -0.000113 -0.001309 -1.003451  0.079579 -0.015158 -0.009672
#
#     w_x  w_y  w_z       r_x       r_y        r_z       q_w       q_x  \
# 0   0.0  0.0  0.0  4.142828 -1.469554 -75.914314  0.788176 -0.020615
# 1   0.0  0.0  0.0  4.142550 -1.469023 -75.914200  0.788177 -0.020616
# 2   0.0  0.0  0.0  4.141570 -1.468998 -75.914284  0.788176 -0.020609
# 3   0.0  0.0  0.0  4.140945 -1.468972 -75.914383  0.788176 -0.020605
# 4   0.0  0.0  0.0  4.142274 -1.468239 -75.914444  0.788175 -0.020618
# 5   0.0  0.0  0.0  3.764982 -1.339337 -75.749550  0.789110 -0.018757
# 6   0.0  0.0  0.0  3.765075 -1.339289 -75.749809  0.789109 -0.018758
# 7   0.0  0.0  0.0  3.765701 -1.339239 -75.750092  0.789107 -0.018762
# 8   0.0  0.0  0.0  3.766131 -1.339251 -75.749840  0.789108 -0.018765
# 9   0.0  0.0  0.0  3.765672 -1.338916 -75.749565  0.789110 -0.018764
# 10  0.0  0.0  0.0  3.317834 -1.213347 -75.595284  0.789993 -0.016388
# 11  0.0  0.0  0.0  3.317580 -1.212914 -75.595886  0.789989 -0.016388
# 12  0.0  0.0  0.0  3.317672 -1.212868 -75.596146  0.789988 -0.016389
# 13  0.0  0.0  0.0  3.318481 -1.212975 -75.596588  0.789985 -0.016394
# 14  0.0  0.0  0.0  3.316948 -1.212486 -75.596123  0.789988 -0.016386
# 15  0.0  0.0  0.0  2.507025 -0.955235 -75.323120  0.791528 -0.012225
# 16  0.0  0.0  0.0  2.505694 -0.955373 -75.323364  0.791527 -0.012215
# 17  0.0  0.0  0.0  2.505962 -0.955330 -75.323647  0.791525 -0.012217
# 18  0.0  0.0  0.0  2.505873 -0.954587 -75.323875  0.791524 -0.012221
# 19  0.0  0.0  0.0  2.505580 -0.954296 -75.323097  0.791528 -0.012220
# 20  0.0  0.0  0.0  2.143319 -0.808547 -75.184937  0.792292 -0.010516
#
#          q_y       q_z
# 0   0.032335  0.614254
# 1   0.032330  0.614254
# 2   0.032324  0.614255
# 3   0.032321  0.614255
# 4   0.032323  0.614256
# 5   0.029387  0.613261
# 6   0.029387  0.613263
# 7   0.029390  0.613265
# 8   0.029393  0.613263
# 9   0.029388  0.613262
# 10  0.026105  0.612341
# 11  0.026100  0.612345
# 12  0.026101  0.612347
# 13  0.026106  0.612350
# 14  0.026094  0.612347
# 15  0.019963  0.610684
# 16  0.019957  0.610686
# 17  0.019958  0.610688
# 18  0.019953  0.610690
# 19  0.019949  0.610685
# 20  0.016999  0.609815

# %%
POSE_MAP= {
    "rett": 0,
    "framover": 1,
    "bakover": 2,
    "venstre": 3,
    "hoyre": 4,
    "overgang": 5
}

def get_timestamp_and_pose(filename):
    rows = []
    with open(filename, "r") as f:
        lines = f.readlines()
        offset = float(lines[1].strip().split(";")[1]) # This offset is the duration spent in the video before recording of data begun.
        for l in lines[1:]:
            sep_row = l.strip().split(";")
            finished_row = [round(float(x)-offset,2) for x in sep_row[1:3]]
            finished_row.append(POSE_MAP[sep_row[3].lower()])
            rows.append(finished_row)
    return rows
            

f_name = "simon_strike_a_pose.txt"
stamped_poses = get_timestamp_and_pose(f_name)
print(stamped_poses)

df_stamped_poses = []
index = 0
for stamp in df["Timestamp"]:  
    if stamp <= stamped_poses[-1][1]: 
        if stamp > stamped_poses[index][1]:
            index += 1
        else if stamp < stamped_poses[index][0]:

        df_stamped_poses.append(stamped_poses[index][2])
        
    # If timestamp of the data point exceeds last timestamp recorded by the annotation, append default -1 value
    else:
        df_stamped_poses.append(-1)

#print(df_stamped_poses)

df["Pose"] = df_stamped_poses
#print(df[2400:2500][:])

#df['Pose'].hist(bins=4)
sns.lineplot(data=df, x="Timestamp", y='Pose')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-a2897ce8582e> in <module>
#      21
#      22 f_name = "simon_strike_a_pose.txt"
# ---> 23 stamped_poses = get_timestamp_and_pose(f_name)
#      24 print(stamped_poses)
#      25
#
# <ipython-input-13-a2897ce8582e> in get_timestamp_and_pose(filename)
#      15             sep_row = l.strip().split(";")
#      16             finished_row = [round(float(x)-offset,2) for x in sep_row[1:3]]
# ---> 17             finished_row.append(POSE_MAP[sep_row[3].lower()])
#      18             rows.append(finished_row)
#      19     return rows
#
# KeyError: 'bra'
