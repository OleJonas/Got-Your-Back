# %% [markdown]
# ## Import

# %%
import sys; sys.path.insert(0, '..')
import os
import time
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from tabulate import tabulate
from dataclasses import dataclass
from keras.models import Sequential
from keras.layers import Conv1D, ZeroPadding1D, MaxPooling1D, BatchNormalization, Activation, Dropout, Flatten, Dense, LSTM
from keras.utils import to_categorical
from keras.optimizers import RMSprop, Adam
from keras.losses import CategoricalCrossentropy
from keras import activations
from sklearn.metrics import confusion_matrix
from utils.df_utils import df_wrapper
from utils.declarations import training_files, testing_files, POSE_MAP

# %% [markdown]
# ## Define data

# %%
AMOUNT_OF_SENSORS = 3
VALIDATION_TESTSET = "004"

# %% [markdown]
# ## Datapreparation

# %% [markdown]
# ### Train

# %%
x_train_arr = []
for key in training_files:
    elem = df_wrapper(training_files[key].csv_file)
    elem.concat_sensor_data(AMOUNT_OF_SENSORS)
    elem.align_poses(training_files[key].annot_file, POSE_MAP)
    x_train_arr.append(elem)

x_train = pd.concat([x.df.drop([' TimeStamp (s)', 'Pose'],axis=1) for x in x_train_arr])
y_train = pd.concat([x.df['Pose'] for x in x_train_arr])
# Out:
# ../utils/df_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \

# %% [markdown]
# ### Test

# %%
x_test_dict = dict()
y_test_dict = dict()
for key in testing_files:
    elem = df_wrapper(testing_files[key].csv_file)
    elem.concat_sensor_data(AMOUNT_OF_SENSORS)
    elem.align_poses(testing_files[key].annot_file, POSE_MAP)
    y_test = elem.df["Pose"]
    y_test.index = [i for i in range(len(y_test))]
    x_test_dict[key] = elem.df
    y_test_dict[key] = y_test

x_test = x_test_dict[VALIDATION_TESTSET].drop([' TimeStamp (s)', 'Pose'], axis=1) 
y_test = y_test_dict[VALIDATION_TESTSET]
# Out:
# ../utils/df_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \

# %% [markdown]
# ## Visualisation

# %%
cols = []
height=30
width=(height/2)*len(x_train_arr)
fig, axes = plt.subplots(4, len(x_train_arr), figsize=(width, height))
fig.suptitle('Data visualisation')
# Train
for i, elem in enumerate(x_train_arr):
    sns.lineplot(ax=axes[0, i], data=elem.df, x=" TimeStamp (s)", y='Pose')
    sns.histplot(ax=axes[1, i], data=elem.df["Pose"])
    cols.append(f'Train {key}')    
for ax, col in zip(axes[0], cols):
    ax.set_title(col)
# Test
cols=[]
for i, key in enumerate(x_test_dict):
    sns.lineplot(ax=axes[2, i], data=x_test_dict[key], x=" TimeStamp (s)", y='Pose')
    sns.histplot(ax=axes[3, i], data=y_test_dict[key])
    cols.append(f'Test {key}') 
for ax, col in zip(axes[2], cols):
    ax.set_title(col)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Adjust dataframes

# %%
# Create numpy arrays
x_train_numpy = x_train.values
x_test_numpy = x_test.values
y_train_numpy = y_train.values
y_test_numpy = y_test.values

# Hot encode categories into numbers
y_train = to_categorical(y_train_numpy,9)
y_test = to_categorical(y_test_numpy,9)

# Change shape for CNN
x_train_numpy = x_train_numpy.reshape(x_train_numpy.shape[0],x_train_numpy.shape[1], 1)
x_test_numpy = x_test_numpy.reshape(x_test_numpy.shape[0],x_test_numpy.shape[1], 1)

# %% [markdown]
# ## Hyperparams

# %%
EPOCH = 20
BATCH_SIZE = 64 # 256
LR = 0.00075
OPTIM = Adam(learning_rate=LR)
# OPTIM = RMSPROP(learning_rate=LR)

# Shapes
INPUT_SHAPE = (x_train_numpy.shape[1], 1)
OUTPUT_SHAPE = 9

# %% [markdown]
# ## Model

# %%
model = Sequential()
model.add(Conv1D(128, kernel_size=3, padding="same", activation=activations.relu, input_shape=INPUT_SHAPE))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=(2)))
model.add(Conv1D(128, kernel_size=3, padding="same", activation=activations.relu))
mode.add(LSTM(128, return_sequences=True)(conv1))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=(2)))
model.add(Flatten())
model.add(Dense(64, activation=activations.tanh))
model.add(Dropout(0.2))
model.add(Dense(32, activation=activations.tanh))
model.add(Dropout(0.2))
model.add(Dense(16, activation=activations.relu))
model.add(Dropout(0.2))
model.add(Dense(OUTPUT_SHAPE, activation=activations.softmax))
model.summary()
model.compile(optimizer=OPTIM, loss=CategoricalCrossentropy(), metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0c6eb6c69646> in <module>
#       4 model.add(MaxPooling1D(pool_size=(2)))
#       5 model.add(Conv1D(128, kernel_size=3, padding="same", activation=activations.relu))
# ----> 6 mode.add(LSTM(128, return_sequences=True)(conv1))
#       7 model.add(BatchNormalization())
#       8 model.add(MaxPooling1D(pool_size=(2)))
#
# NameError: name 'mode' is not defined

# %% [markdown]
# ## Fit the model

# %%
model.fit(x=x_train_numpy, y=y_train, batch_size=BATCH_SIZE, validation_data=(x_test_numpy, y_test), shuffle=True, epochs=EPOCH)
# Out:
# Epoch 1/20
# 6559/6559 [==============================] - 65s 10ms/step - loss: 0.5142 - accuracy: 0.8303 - val_loss: 1.9538 - val_accuracy: 0.4795
# Epoch 2/20
# 6559/6559 [==============================] - 62s 10ms/step - loss: 0.1646 - accuracy: 0.9531 - val_loss: 2.4879 - val_accuracy: 0.5841
# Epoch 3/20
# 6559/6559 [==============================] - 62s 10ms/step - loss: 0.1270 - accuracy: 0.9626 - val_loss: 2.7414 - val_accuracy: 0.6098
# Epoch 4/20
# 6559/6559 [==============================] - 62s 10ms/step - loss: 0.1133 - accuracy: 0.9665 - val_loss: 4.4245 - val_accuracy: 0.4219
# Epoch 5/20
# 6559/6559 [==============================] - 62s 9ms/step - loss: 0.0961 - accuracy: 0.9714 - val_loss: 2.6192 - val_accuracy: 0.6387
# Epoch 6/20
# 6559/6559 [==============================] - 62s 9ms/step - loss: 0.0905 - accuracy: 0.9726 - val_loss: 5.3031 - val_accuracy: 0.4477
# Epoch 7/20
# 6559/6559 [==============================] - 61s 9ms/step - loss: 0.0847 - accuracy: 0.9748 - val_loss: 2.4977 - val_accuracy: 0.6857
# Epoch 8/20
# 6559/6559 [==============================] - 61s 9ms/step - loss: 0.0794 - accuracy: 0.9760 - val_loss: 4.9563 - val_accuracy: 0.4432
# Epoch 9/20
# 6559/6559 [==============================] - 62s 9ms/step - loss: 0.0759 - accuracy: 0.9776 - val_loss: 3.1492 - val_accuracy: 0.5322
# Epoch 10/20
# 6559/6559 [==============================] - 61s 9ms/step - loss: 0.0726 - accuracy: 0.9778 - val_loss: 6.6116 - val_accuracy: 0.4368
# Epoch 11/20
# 6559/6559 [==============================] - 61s 9ms/step - loss: 0.0696 - accuracy: 0.9783 - val_loss: 3.2423 - val_accuracy: 0.5381
# Epoch 12/20
# 6559/6559 [==============================] - 60s 9ms/step - loss: 0.0700 - accuracy: 0.9787 - val_loss: 6.2529 - val_accuracy: 0.5630
# Epoch 13/20
# 6559/6559 [==============================] - 60s 9ms/step - loss: 0.0677 - accuracy: 0.9792 - val_loss: 6.5420 - val_accuracy: 0.4071
# Epoch 14/20
# 6559/6559 [==============================] - 59s 9ms/step - loss: 0.0629 - accuracy: 0.9808 - val_loss: 6.2930 - val_accuracy: 0.5261
# Epoch 15/20
# 6559/6559 [==============================] - 59s 9ms/step - loss: 0.0635 - accuracy: 0.9811 - val_loss: 7.0088 - val_accuracy: 0.4551
# Epoch 16/20
# 6559/6559 [==============================] - 60s 9ms/step - loss: 0.0610 - accuracy: 0.9816 - val_loss: 3.8710 - val_accuracy: 0.4900
# Epoch 17/20
# 6559/6559 [==============================] - 59s 9ms/step - loss: 0.0605 - accuracy: 0.9818 - val_loss: 3.7075 - val_accuracy: 0.4800
# Epoch 18/20
# 6559/6559 [==============================] - 60s 9ms/step - loss: 0.0607 - accuracy: 0.9817 - val_loss: 3.9461 - val_accuracy: 0.4595
# Epoch 19/20
# 6559/6559 [==============================] - 60s 9ms/step - loss: 0.0581 - accuracy: 0.9824 - val_loss: 3.1878 - val_accuracy: 0.6136
# Epoch 20/20
# 6559/6559 [==============================] - 60s 9ms/step - loss: 0.0578 - accuracy: 0.9823 - val_loss: 4.5256 - val_accuracy: 0.4598

# %% [markdown]
# ## Visualise the loss

# %%
history = pd.DataFrame(model.history.history)
history.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Precision

# %%
print("Classification accuracy:")
classification_dict = dict()

for key in x_test_dict:
    x_test_numpy = x_test_dict[key].drop([' TimeStamp (s)', 'Pose'], axis=1).values
    x_test_numpy = x_test_numpy.reshape(x_test_numpy.shape[0],x_test_numpy.shape[1], 1)
    classify = model.predict(x_test_numpy)
    classifications = [i.argmax() for i in classify]
    annotated_positions = y_test_dict[key].to_numpy()
    correct_classifications = (classifications == annotated_positions).sum()
    
    print(f"{key}: {round(correct_classifications/len(classifications)*100,2)}%")
    classification_dict[key] = classifications
# Out:
# Classification accuracy:
# 001: 64.52%
# 004: 45.98%
# 005: 77.27%
# 006: 62.86%
# 007: 65.38%
# 008: 56.07%

# %% [markdown]
# ## Visualise classification

# %%
width=16
height=4*len(x_test_dict)
fig, axes = plt.subplots(len(x_test_dict), 4, figsize=(width, height))
for i, key in enumerate(x_test_dict):
    cols = [f"{key}: Model classifications", f"{key}: Model heatmap", f"{key}: Annotated classifications", f"{key}: Annotated heatmap"]
    df_predict = pd.DataFrame({' Timestamp (s)': x_test_dict[key][' TimeStamp (s)'],'Pose':classification_dict[key]})
    sns.lineplot(ax=axes[i, 0], data=df_predict,x=' Timestamp (s)',y='Pose')
    sns.heatmap(ax=axes[i, 1], data=confusion_matrix(y_test_dict[key], classification_dict[key]), cmap="YlGnBu", annot=True, fmt="d")
    sns.lineplot(ax=axes[i, 2], data=x_test_dict[key], x=" TimeStamp (s)", y='Pose')
    sns.heatmap(ax=axes[i, 3], data=confusion_matrix(y_test_dict[key], y_test_dict[key].to_numpy()), cmap="YlGnBu", annot=True, fmt="d")
    for ax, col in zip(axes[i], cols): ax.set_title(col)
fig.tight_layout()
plt.show()

# %%
path = f"../models/CNN_model_{AMOUNT_OF_SENSORS}.h5"
model.save(path)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=59d486bc-e14d-4632-9064-12272fc72d11' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
