# %% [markdown]
# ## Import

# %%
import sys; sys.path.insert(0, '..')
import os
import time
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from tabulate import tabulate
from dataclasses import dataclass
from keras.models import Sequential
from keras.layers import Conv1D, ZeroPadding1D, AveragePooling1D, MaxPooling1D, BatchNormalization, Activation, Dropout, Flatten, Dense
from keras.utils import to_categorical
from keras.optimizers import RMSprop, Adam
from keras.losses import CategoricalCrossentropy
from keras import activations
from sklearn.metrics import confusion_matrix
from utils.df_utils import df_wrapper
from utils.declarations import training_files, testing_files, POSE_MAP

# %% [markdown]
# ## Define data

# %%
AMOUNT_OF_SENSORS = 1
VALIDATION_TESTSET = "004"

# %% [markdown]
# ## Datapreparation

# %% [markdown]
# ### Train

# %%
x_train_arr = []
for key in training_files:
    elem = df_wrapper(training_files[key].csv_file)
    elem.concat_sensor_data(AMOUNT_OF_SENSORS)
    elem.align_poses(training_files[key].annot_file, POSE_MAP)
    x_train_arr.append(elem)

x_train = pd.concat([x.df.drop([' TimeStamp (s)', 'Pose'],axis=1) for x in x_train_arr])
y_train = pd.concat([x.df['Pose'] for x in x_train_arr])
# Out:
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \

# %% [markdown]
# ### Test

# %%
x_test_dict = dict()
y_test_dict = dict()
for key in testing_files:
    elem = df_wrapper(testing_files[key].csv_file)
    elem.concat_sensor_data(AMOUNT_OF_SENSORS)
    elem.align_poses(testing_files[key].annot_file, POSE_MAP)
    y_test = elem.df["Pose"]
    y_test.index = [i for i in range(len(y_test))]
    x_test_dict[key] = elem.df
    y_test_dict[key] = y_test

x_test = x_test_dict[VALIDATION_TESTSET].drop([' TimeStamp (s)', 'Pose'], axis=1) 
y_test = y_test_dict[VALIDATION_TESTSET]
# Out:
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \
# ../utils/df_utils.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_arr[i][" TimeStamp (s)"] = self.df_arr[i][" TimeStamp (s)"] - \

# %% [markdown]
# ## Visualisation

# %%
cols = []
height=30
width=(height/2)*len(x_train_arr)
fig, axes = plt.subplots(4, max(len(training_files), len(testing_files)), figsize=(width, height))
fig.suptitle('Data visualisation')
# Train
for i, elem in enumerate(x_train_arr):
    sns.lineplot(ax=axes[0, i], data=elem.df, x=" TimeStamp (s)", y='Pose')
    sns.histplot(ax=axes[1, i], data=elem.df["Pose"])
    cols.append(f'Train 00{i+1}')    
for ax, col in zip(axes[0], cols):
    ax.set_title(col)
# Test
cols=[]
for i, key in enumerate(x_test_dict):
    sns.lineplot(ax=axes[2, i], data=x_test_dict[key], x=" TimeStamp (s)", y='Pose')
    sns.histplot(ax=axes[3, i], data=y_test_dict[key])
    cols.append(f'Test {key}') 
for ax, col in zip(axes[2], cols):
    ax.set_title(col)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Adjust dataframes

# %%
# Create numpy arrays
x_train_numpy = x_train.values
x_test_numpy = x_test.values
y_train_numpy = y_train.values
y_test_numpy = y_test.values

# Hot encode categories into numbers
y_train = to_categorical(y_train_numpy,9)
y_test = to_categorical(y_test_numpy,9)

# Change shape for CNN
x_train_numpy = x_train_numpy.reshape(x_train_numpy.shape[0],x_train_numpy.shape[1], 1)
x_test_numpy = x_test_numpy.reshape(x_test_numpy.shape[0],x_test_numpy.shape[1], 1)

# %% [markdown]
# ## Hyperparams

# %%
EPOCH = 40
BATCH_SIZE = 192 # 256
LR = 0.0000025
OPTIM = Adam(learning_rate=LR)
# OPTIM = RMSprop(learning_rate=LR)

# Shapes
INPUT_SHAPE = (x_train_numpy.shape[1], 1)
OUTPUT_SHAPE = 9

# %% [markdown]
# ## Model

# %%
model = Sequential()
model.add(Conv1D(128, kernel_size=4, padding="same", activation=activations.relu, input_shape=INPUT_SHAPE)) #3
model.add(BatchNormalization())
model.add(AveragePooling1D(pool_size=(2))) #2
model.add(Dropout(0.2))
model.add(Conv1D(128, kernel_size=4, padding="same", activation=activations.relu)) #3
model.add(BatchNormalization())
model.add(AveragePooling1D(pool_size=(2))) #2
model.add(Flatten())
model.add(Dense(64, activation=activations.tanh))
model.add(Dropout(0.2))
model.add(Dense(32, activation=activations.tanh))
model.add(Dropout(0.2))
model.add(Dense(16, activation=activations.relu))
model.add(Dropout(0.2))
model.add(Dense(OUTPUT_SHAPE, activation=activations.softmax))
model.summary()
model.compile(optimizer=OPTIM, loss=CategoricalCrossentropy(), metrics=['accuracy'])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 13, 128)           640
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 13, 128)           512
# _________________________________________________________________
# average_pooling1d_6 (Average (None, 6, 128)            0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 6, 128)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 6, 128)            65664
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 6, 128)            512
# _________________________________________________________________
# average_pooling1d_7 (Average (None, 3, 128)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                24640
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 9)                 153
# =================================================================
# Total params: 94,729
# Trainable params: 94,217
# Non-trainable params: 512
# _________________________________________________________________

# %% [markdown]
# ## Fit the model

# %%
model.fit(x=x_train_numpy, y=y_train, batch_size=BATCH_SIZE, validation_data=(x_test_numpy, y_test), shuffle=True, epochs=EPOCH)
# Out:
# Epoch 1/40
# 2441/2441 [==============================] - 57s 23ms/step - loss: 2.1866 - accuracy: 0.1519 - val_loss: 2.2009 - val_accuracy: 0.1138
# Epoch 2/40
# 2441/2441 [==============================] - 55s 23ms/step - loss: 2.0825 - accuracy: 0.2053 - val_loss: 2.0968 - val_accuracy: 0.2120
# Epoch 3/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 1.9698 - accuracy: 0.2634 - val_loss: 1.9659 - val_accuracy: 0.2645
# Epoch 4/40
# 2441/2441 [==============================] - 57s 24ms/step - loss: 1.8535 - accuracy: 0.3150 - val_loss: 1.8328 - val_accuracy: 0.3116
# Epoch 5/40
# 2441/2441 [==============================] - 57s 24ms/step - loss: 1.7441 - accuracy: 0.3583 - val_loss: 1.7084 - val_accuracy: 0.3330
# Epoch 6/40
# 2441/2441 [==============================] - 62s 26ms/step - loss: 1.6453 - accuracy: 0.3959 - val_loss: 1.6035 - val_accuracy: 0.4079
# Epoch 7/40
# 2441/2441 [==============================] - 80s 33ms/step - loss: 1.5592 - accuracy: 0.4283 - val_loss: 1.5060 - val_accuracy: 0.4350
# Epoch 8/40
# 2441/2441 [==============================] - 79s 32ms/step - loss: 1.4824 - accuracy: 0.4580 - val_loss: 1.4159 - val_accuracy: 0.4588
# Epoch 9/40
# 2441/2441 [==============================] - 81s 33ms/step - loss: 1.4127 - accuracy: 0.4852 - val_loss: 1.3244 - val_accuracy: 0.5013
# Epoch 10/40
# 2441/2441 [==============================] - 81s 33ms/step - loss: 1.3506 - accuracy: 0.5089 - val_loss: 1.2599 - val_accuracy: 0.5200
# Epoch 11/40
# 2441/2441 [==============================] - 80s 33ms/step - loss: 1.2929 - accuracy: 0.5305 - val_loss: 1.2006 - val_accuracy: 0.5385
# Epoch 12/40
# 2441/2441 [==============================] - 81s 33ms/step - loss: 1.2393 - accuracy: 0.5514 - val_loss: 1.1406 - val_accuracy: 0.5511
# Epoch 13/40
# 2441/2441 [==============================] - 81s 33ms/step - loss: 1.1924 - accuracy: 0.5673 - val_loss: 1.0973 - val_accuracy: 0.5608
# Epoch 14/40
# 2441/2441 [==============================] - 81s 33ms/step - loss: 1.1477 - accuracy: 0.5835 - val_loss: 1.0518 - val_accuracy: 0.5683
# Epoch 15/40
# 2441/2441 [==============================] - 81s 33ms/step - loss: 1.1062 - accuracy: 0.5987 - val_loss: 1.0061 - val_accuracy: 0.5752
# Epoch 16/40
# 2441/2441 [==============================] - 69s 28ms/step - loss: 1.0699 - accuracy: 0.6109 - val_loss: 0.9766 - val_accuracy: 0.5799
# Epoch 17/40
# 2441/2441 [==============================] - 59s 24ms/step - loss: 1.0368 - accuracy: 0.6219 - val_loss: 0.9440 - val_accuracy: 0.5854
# Epoch 18/40
# 2441/2441 [==============================] - 57s 23ms/step - loss: 1.0041 - accuracy: 0.6338 - val_loss: 0.9104 - val_accuracy: 0.5895
# Epoch 19/40
# 2441/2441 [==============================] - 54s 22ms/step - loss: 0.9769 - accuracy: 0.6433 - val_loss: 0.8886 - val_accuracy: 0.5944
# Epoch 20/40
# 2441/2441 [==============================] - 57s 23ms/step - loss: 0.9506 - accuracy: 0.6537 - val_loss: 0.8693 - val_accuracy: 0.5942
# Epoch 21/40
# 2441/2441 [==============================] - 59s 24ms/step - loss: 0.9236 - accuracy: 0.6627 - val_loss: 0.8485 - val_accuracy: 0.5954
# Epoch 22/40
# 2441/2441 [==============================] - 57s 23ms/step - loss: 0.9005 - accuracy: 0.6716 - val_loss: 0.8233 - val_accuracy: 0.5979
# Epoch 23/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 0.8783 - accuracy: 0.6800 - val_loss: 0.7970 - val_accuracy: 0.6077
# Epoch 24/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 0.8567 - accuracy: 0.6881 - val_loss: 0.7984 - val_accuracy: 0.5989
# Epoch 25/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 0.8362 - accuracy: 0.6957 - val_loss: 0.7917 - val_accuracy: 0.6005
# Epoch 26/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 0.8191 - accuracy: 0.7009 - val_loss: 0.7700 - val_accuracy: 0.6005
# Epoch 27/40
# 2441/2441 [==============================] - 57s 23ms/step - loss: 0.8012 - accuracy: 0.7076 - val_loss: 0.7617 - val_accuracy: 0.5959
# Epoch 28/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 0.7820 - accuracy: 0.7161 - val_loss: 0.7419 - val_accuracy: 0.6065
# Epoch 29/40
# 2441/2441 [==============================] - 57s 24ms/step - loss: 0.7683 - accuracy: 0.7201 - val_loss: 0.7368 - val_accuracy: 0.6040
# Epoch 30/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 0.7519 - accuracy: 0.7263 - val_loss: 0.7357 - val_accuracy: 0.5928
# Epoch 31/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 0.7374 - accuracy: 0.7324 - val_loss: 0.7307 - val_accuracy: 0.5871
# Epoch 32/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 0.7238 - accuracy: 0.7373 - val_loss: 0.7104 - val_accuracy: 0.6033
# Epoch 33/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 0.7114 - accuracy: 0.7411 - val_loss: 0.7051 - val_accuracy: 0.6052
# Epoch 34/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 0.6971 - accuracy: 0.7475 - val_loss: 0.7111 - val_accuracy: 0.5964
# Epoch 35/40
# 2441/2441 [==============================] - 57s 23ms/step - loss: 0.6874 - accuracy: 0.7508 - val_loss: 0.7213 - val_accuracy: 0.5849
# Epoch 36/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 0.6744 - accuracy: 0.7552 - val_loss: 0.6844 - val_accuracy: 0.6110
# Epoch 37/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 0.6645 - accuracy: 0.7585 - val_loss: 0.7007 - val_accuracy: 0.5947
# Epoch 38/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 0.6534 - accuracy: 0.7636 - val_loss: 0.6925 - val_accuracy: 0.5902
# Epoch 39/40
# 2441/2441 [==============================] - 59s 24ms/step - loss: 0.6415 - accuracy: 0.7685 - val_loss: 0.6709 - val_accuracy: 0.6226
# Epoch 40/40
# 2441/2441 [==============================] - 58s 24ms/step - loss: 0.6326 - accuracy: 0.7715 - val_loss: 0.6921 - val_accuracy: 0.5966

# %% [markdown]
# ## Visualise the loss

# %%
history = pd.DataFrame(model.history.history)
history.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Precision

# %%
print("Classification accuracy:")
classification_dict = dict()
accuracy_list = list() 

for key in x_test_dict:
    x_test_numpy = x_test_dict[key].drop([' TimeStamp (s)', 'Pose'], axis=1).values
    x_test_numpy = x_test_numpy.reshape(x_test_numpy.shape[0],x_test_numpy.shape[1], 1)
    classify = model.predict(x_test_numpy)
    classifications = [i.argmax() for i in classify]
    annotated_positions = y_test_dict[key].to_numpy()
    correct_classifications = (classifications == annotated_positions).sum()
    accuracy_list.append(round(correct_classifications/len(classifications)*100,2))
    print(f"{key}: {accuracy_list[-1]}%")
    classification_dict[key] = classifications

print(f"Average accuracy: {round(sum(accuracy_list)/len(accuracy_list),2)}%")
# Out:
# Classification accuracy:
# 001: 86.14%
# 002: 46.66%
# 004: 59.66%
# 005: 60.16%
# 006: 54.89%
# 007: 56.41%
# 009: 59.83%
# 010: 39.66%
# Average accuracy: 57.93%

# %% [markdown]
# ## Visualise classification

# %%
width=16
height=4*len(x_test_dict)
fig, axes = plt.subplots(len(x_test_dict), 4, figsize=(width, height))
for i, key in enumerate(x_test_dict):
    cols = [f"{key}: Model classifications", f"{key}: Model heatmap", f"{key}: Annotated classifications", f"{key}: Annotated heatmap"]
    df_predict = pd.DataFrame({' Timestamp (s)': x_test_dict[key][' TimeStamp (s)'],'Pose':classification_dict[key]})
    sns.lineplot(ax=axes[i, 0], data=df_predict,x=' Timestamp (s)',y='Pose')
    sns.heatmap(ax=axes[i, 1], data=confusion_matrix(y_test_dict[key], classification_dict[key]), cmap="YlGnBu", annot=True, fmt="d")
    sns.lineplot(ax=axes[i, 2], data=x_test_dict[key], x=" TimeStamp (s)", y='Pose')
    sns.heatmap(ax=axes[i, 3], data=confusion_matrix(y_test_dict[key], y_test_dict[key].to_numpy()), cmap="YlGnBu", annot=True, fmt="d")
    for ax, col in zip(axes[i], cols): ax.set_title(col)
fig.tight_layout()
plt.show()

# %%
"""
path = f"../models/CNN_model_{AMOUNT_OF_SENSORS}.h5"
model.save(path)
"""
# Out:
# '\npath = f"../models/CNN_model_{AMOUNT_OF_SENSORS}.h5"\nmodel.save(path)\n'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=59d486bc-e14d-4632-9064-12272fc72d11' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
