# %%
import sys; sys.path.insert(0, '..')
import os
import time
import pandas as pd
import keras
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from tabulate import tabulate
from dataclasses import dataclass
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.utils import to_categorical
from keras.optimizers import RMSprop, Adam
from keras.losses import CategoricalCrossentropy
from keras import activations
from sklearn.metrics import confusion_matrix
from utils.df_utils import df_wrapper
from utils.declarations import training_files, testing_files, POSE_MAP

# %%
AMOUNT_OF_SENSORS = 3
VALIDATION_TESTSET = "004"

# %%
x_train_arr = []
for key in training_files:
    elem = df_wrapper(training_files[key].csv_file)
    elem.concat_sensor_data(AMOUNT_OF_SENSORS)
    elem.align_poses(training_files[key].annot_file, POSE_MAP)
    x_train_arr.append(elem)

x_train = pd.concat([x.df.drop([' TimeStamp (s)', 'Pose'],axis=1) for x in x_train_arr])
y_train = pd.concat([x.df['Pose'] for x in x_train_arr])

# %%
x_test_dict = dict()
y_test_dict = dict()
for key in testing_files:
    elem = df_wrapper(testing_files[key].csv_file)
    elem.concat_sensor_data(AMOUNT_OF_SENSORS)
    elem.align_poses(testing_files[key].annot_file, POSE_MAP)
    y_test = elem.df["Pose"]
    y_test.index = [i for i in range(len(y_test))]
    x_test_dict[key] = elem.df
    y_test_dict[key] = y_test
    print(key)

x_test = x_test_dict[VALIDATION_TESTSET].drop([' TimeStamp (s)', 'Pose'], axis=1) 
y_test = y_test_dict[VALIDATION_TESTSET]
# Out:
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010

# %%
# Create numpy arrays
x_train_numpy = x_train.values
x_test_numpy = x_test.values
y_train_numpy = y_train.values
y_test_numpy = y_test.values

# Hot encode categories into numbers
y_train = to_categorical(y_train_numpy,9)
y_test = to_categorical(y_test_numpy,9)

# %%
print("TRAINING SHAPES")
print("x_train_numpy: ", x_train_numpy.shape)
print("y_train_numpy: ", y_train_numpy.shape)

print("TESTING SHAPES")
print("x_test_numpy: ", x_test_numpy.shape)
print("y_test_numpy: ", y_test_numpy.shape)
# Out:
# TRAINING SHAPES
# x_train_numpy:  (466981, 39)
# y_train_numpy:  (466981,)
# TESTING SHAPES
# x_test_numpy:  (8367, 39)
# y_test_numpy:  (8367,)

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
scaler.fit(x_train_numpy)
scaler.fit(x_test_numpy)
# Out:
# RobustScaler()

# %%
OPTIM = Adam(learning_rate=0.000001)
# OPTIM = RMSprop(learning_rate=LR)

# %%
callbacks = [
    #keras.callbacks.CSVLogger("ANN_3_sensorer_3.csv", separator=",", append=False),
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)
]

# %%
model = Sequential()
# model.add(Dense(256, activation='relu'))
# model.add(Dropout(rate=0.2))
# model.add(Dense(128, activation='relu'))
# model.add(Dropout(rate=0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(rate=0.2))
model.add(Dense(48, activation='relu'))
model.add(Dropout(rate=0.2))
model.add(Dense(24, activation='relu'))
model.add(Dropout(rate=0.2))
model.add(Dense(12, activation='relu'))
model.add(Dropout(rate=0.2))
model.add(Dense(9, activation='softmax'))

model.compile(optimizer=OPTIM, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %%
model.fit(x=x_train_numpy, y=y_train, batch_size=8192, epochs=2000, validation_data=(x_test_numpy, y_test))
# Out:
# 1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3967 - accuracy: 0.8745 - val_loss: 0.4143 - val_accuracy: 0.8971
# Epoch 546/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3938 - accuracy: 0.8756 - val_loss: 0.4135 - val_accuracy: 0.8972
# Epoch 547/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3926 - accuracy: 0.8759 - val_loss: 0.4126 - val_accuracy: 0.8972
# Epoch 548/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3913 - accuracy: 0.8763 - val_loss: 0.4118 - val_accuracy: 0.8972
# Epoch 549/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3910 - accuracy: 0.8764 - val_loss: 0.4109 - val_accuracy: 0.8973
# Epoch 550/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3876 - accuracy: 0.8776 - val_loss: 0.4099 - val_accuracy: 0.8973
# Epoch 551/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3871 - accuracy: 0.8781 - val_loss: 0.4099 - val_accuracy: 0.8973
# Epoch 552/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3862 - accuracy: 0.8778 - val_loss: 0.4094 - val_accuracy: 0.8973
# Epoch 553/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3835 - accuracy: 0.8789 - val_loss: 0.4085 - val_accuracy: 0.8972
# Epoch 554/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3809 - accuracy: 0.8802 - val_loss: 0.4079 - val_accuracy: 0.8973
# Epoch 555/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3780 - accuracy: 0.8811 - val_loss: 0.4073 - val_accuracy: 0.8972
# Epoch 556/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3787 - accuracy: 0.8808 - val_loss: 0.4066 - val_accuracy: 0.8972
# Epoch 557/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3784 - accuracy: 0.8807 - val_loss: 0.4059 - val_accuracy: 0.8972
# Epoch 558/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3758 - accuracy: 0.8814 - val_loss: 0.4054 - val_accuracy: 0.8973
# Epoch 559/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3733 - accuracy: 0.8826 - val_loss: 0.4045 - val_accuracy: 0.8973
# Epoch 560/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3717 - accuracy: 0.8825 - val_loss: 0.4038 - val_accuracy: 0.8975
# Epoch 561/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3697 - accuracy: 0.8833 - val_loss: 0.4033 - val_accuracy: 0.8976
# Epoch 562/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3698 - accuracy: 0.8843 - val_loss: 0.4025 - val_accuracy: 0.8973
# Epoch 563/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3700 - accuracy: 0.8832 - val_loss: 0.4019 - val_accuracy: 0.8973
# Epoch 564/1200
# 58/58 [==============================] - 2s 26ms/step - loss: 0.3679 - accuracy: 0.8843 - val_loss: 0.4016 - val_accuracy: 0.8971
# Epoch 565/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3640 - accuracy: 0.8863 - val_loss: 0.4010 - val_accuracy: 0.8971
# Epoch 566/1200
# 58/58 [==============================] - 2s 26ms/step - loss: 0.3644 - accuracy: 0.8860 - val_loss: 0.4003 - val_accuracy: 0.8972
# Epoch 567/1200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.3617 - accuracy: 0.8869 - val_loss: 0.4002 - val_accuracy: 0.8973
# Epoch 568/1200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.3609 - accuracy: 0.8867 - val_loss: 0.3995 - val_accuracy: 0.8973
# Epoch 569/1200
# 58/58 [==============================] - 1s 25ms/step - loss: 0.3586 - accuracy: 0.8871 - val_loss: 0.3992 - val_accuracy: 0.8973
# Epoch 570/1200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.3586 - accuracy: 0.8875 - val_loss: 0.3981 - val_accuracy: 0.8973
# Epoch 571/1200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.3566 - accuracy: 0.8886 - val_loss: 0.3973 - val_accuracy: 0.8972
# Epoch 572/1200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.3565 - accuracy: 0.8882 - val_loss: 0.3967 - val_accuracy: 0.8975
# Epoch 573/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3548 - accuracy: 0.8892 - val_loss: 0.3961 - val_accuracy: 0.8973
# Epoch 574/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3540 - accuracy: 0.8887 - val_loss: 0.3957 - val_accuracy: 0.8973
# Epoch 575/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3505 - accuracy: 0.8903 - val_loss: 0.3951 - val_accuracy: 0.8973
# Epoch 576/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3498 - accuracy: 0.8906 - val_loss: 0.3945 - val_accuracy: 0.8972
# Epoch 577/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3485 - accuracy: 0.8906 - val_loss: 0.3938 - val_accuracy: 0.8972
# Epoch 578/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3479 - accuracy: 0.8916 - val_loss: 0.3931 - val_accuracy: 0.8972
# Epoch 579/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3462 - accuracy: 0.8926 - val_loss: 0.3930 - val_accuracy: 0.8972
# Epoch 580/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3445 - accuracy: 0.8917 - val_loss: 0.3926 - val_accuracy: 0.8976
# Epoch 581/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3455 - accuracy: 0.8916 - val_loss: 0.3920 - val_accuracy: 0.8975
# Epoch 582/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3410 - accuracy: 0.8933 - val_loss: 0.3921 - val_accuracy: 0.8975
# Epoch 583/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3396 - accuracy: 0.8940 - val_loss: 0.3926 - val_accuracy: 0.8976
# Epoch 584/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3407 - accuracy: 0.8934 - val_loss: 0.3917 - val_accuracy: 0.8975
# Epoch 585/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3387 - accuracy: 0.8940 - val_loss: 0.3912 - val_accuracy: 0.8973
# Epoch 586/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3390 - accuracy: 0.8938 - val_loss: 0.3904 - val_accuracy: 0.8975
# Epoch 587/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3350 - accuracy: 0.8956 - val_loss: 0.3900 - val_accuracy: 0.8973
# Epoch 588/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3343 - accuracy: 0.8954 - val_loss: 0.3894 - val_accuracy: 0.8976
# Epoch 589/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3340 - accuracy: 0.8961 - val_loss: 0.3890 - val_accuracy: 0.8976
# Epoch 590/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3318 - accuracy: 0.8971 - val_loss: 0.3894 - val_accuracy: 0.8977
# Epoch 591/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3305 - accuracy: 0.8970 - val_loss: 0.3886 - val_accuracy: 0.8978
# Epoch 592/1200
# 58/58 [==============================] - 2s 26ms/step - loss: 0.3310 - accuracy: 0.8968 - val_loss: 0.3876 - val_accuracy: 0.8975
# Epoch 593/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3262 - accuracy: 0.8984 - val_loss: 0.3872 - val_accuracy: 0.8975
# Epoch 594/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3261 - accuracy: 0.8987 - val_loss: 0.3867 - val_accuracy: 0.8975
# Epoch 595/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3246 - accuracy: 0.8990 - val_loss: 0.3864 - val_accuracy: 0.8975
# Epoch 596/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3266 - accuracy: 0.8979 - val_loss: 0.3864 - val_accuracy: 0.8976
# Epoch 597/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3245 - accuracy: 0.8992 - val_loss: 0.3862 - val_accuracy: 0.8976
# Epoch 598/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3230 - accuracy: 0.8996 - val_loss: 0.3860 - val_accuracy: 0.8976
# Epoch 599/1200
# 58/58 [==============================] - 2s 29ms/step - loss: 0.3204 - accuracy: 0.9013 - val_loss: 0.3857 - val_accuracy: 0.8975
# Epoch 600/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3192 - accuracy: 0.9005 - val_loss: 0.3847 - val_accuracy: 0.8976
# Epoch 601/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3181 - accuracy: 0.9013 - val_loss: 0.3843 - val_accuracy: 0.8976
# Epoch 602/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3160 - accuracy: 0.9027 - val_loss: 0.3842 - val_accuracy: 0.8976
# Epoch 603/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3140 - accuracy: 0.9034 - val_loss: 0.3839 - val_accuracy: 0.8975
# Epoch 604/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3149 - accuracy: 0.9029 - val_loss: 0.3840 - val_accuracy: 0.8975
# Epoch 605/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3153 - accuracy: 0.9027 - val_loss: 0.3838 - val_accuracy: 0.8973
# Epoch 606/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3125 - accuracy: 0.9036 - val_loss: 0.3831 - val_accuracy: 0.8973
# Epoch 607/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3111 - accuracy: 0.9044 - val_loss: 0.3833 - val_accuracy: 0.8973
# Epoch 608/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3106 - accuracy: 0.9040 - val_loss: 0.3835 - val_accuracy: 0.8975
# Epoch 609/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3103 - accuracy: 0.9034 - val_loss: 0.3825 - val_accuracy: 0.8975
# Epoch 610/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3071 - accuracy: 0.9049 - val_loss: 0.3819 - val_accuracy: 0.8975
# Epoch 611/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3067 - accuracy: 0.9053 - val_loss: 0.3813 - val_accuracy: 0.8976
# Epoch 612/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3066 - accuracy: 0.9055 - val_loss: 0.3808 - val_accuracy: 0.8975
# Epoch 613/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3056 - accuracy: 0.9056 - val_loss: 0.3809 - val_accuracy: 0.8976
# Epoch 614/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.3059 - accuracy: 0.9052 - val_loss: 0.3806 - val_accuracy: 0.8977
# Epoch 615/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3002 - accuracy: 0.9069 - val_loss: 0.3810 - val_accuracy: 0.8978
# Epoch 616/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3011 - accuracy: 0.9070 - val_loss: 0.3808 - val_accuracy: 0.8978
# Epoch 617/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.3005 - accuracy: 0.9071 - val_loss: 0.3806 - val_accuracy: 0.8978
# Epoch 618/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.2998 - accuracy: 0.9074 - val_loss: 0.3804 - val_accuracy: 0.8978
# Epoch 619/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2972 - accuracy: 0.9085 - val_loss: 0.3800 - val_accuracy: 0.8978
# Epoch 620/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2962 - accuracy: 0.9085 - val_loss: 0.3797 - val_accuracy: 0.8979
# Epoch 621/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2967 - accuracy: 0.9078 - val_loss: 0.3792 - val_accuracy: 0.8978
# Epoch 622/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2943 - accuracy: 0.9093 - val_loss: 0.3796 - val_accuracy: 0.8978
# Epoch 623/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.2936 - accuracy: 0.9097 - val_loss: 0.3789 - val_accuracy: 0.8978
# Epoch 624/1200
# 58/58 [==============================] - 2s 26ms/step - loss: 0.2931 - accuracy: 0.9095 - val_loss: 0.3783 - val_accuracy: 0.8977
# Epoch 625/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2926 - accuracy: 0.9092 - val_loss: 0.3782 - val_accuracy: 0.8977
# Epoch 626/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2916 - accuracy: 0.9105 - val_loss: 0.3778 - val_accuracy: 0.8973
# Epoch 627/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2888 - accuracy: 0.9115 - val_loss: 0.3775 - val_accuracy: 0.8975
# Epoch 628/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2888 - accuracy: 0.9112 - val_loss: 0.3767 - val_accuracy: 0.8976
# Epoch 629/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2871 - accuracy: 0.9115 - val_loss: 0.3767 - val_accuracy: 0.8975
# Epoch 630/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2827 - accuracy: 0.9132 - val_loss: 0.3771 - val_accuracy: 0.8975
# Epoch 631/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2853 - accuracy: 0.9123 - val_loss: 0.3771 - val_accuracy: 0.8975
# Epoch 632/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2846 - accuracy: 0.9132 - val_loss: 0.3770 - val_accuracy: 0.8976
# Epoch 633/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2829 - accuracy: 0.9128 - val_loss: 0.3774 - val_accuracy: 0.8976
# Epoch 634/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2822 - accuracy: 0.9128 - val_loss: 0.3774 - val_accuracy: 0.8975
# Epoch 635/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2811 - accuracy: 0.9131 - val_loss: 0.3772 - val_accuracy: 0.8975
# Epoch 636/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2799 - accuracy: 0.9140 - val_loss: 0.3767 - val_accuracy: 0.8975
# Epoch 637/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2781 - accuracy: 0.9149 - val_loss: 0.3764 - val_accuracy: 0.8975
# Epoch 638/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.2776 - accuracy: 0.9144 - val_loss: 0.3756 - val_accuracy: 0.8976
# Epoch 639/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2769 - accuracy: 0.9143 - val_loss: 0.3755 - val_accuracy: 0.8976
# Epoch 640/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2758 - accuracy: 0.9150 - val_loss: 0.3756 - val_accuracy: 0.8976
# Epoch 641/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.2737 - accuracy: 0.9161 - val_loss: 0.3759 - val_accuracy: 0.8976
# Epoch 642/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2747 - accuracy: 0.9155 - val_loss: 0.3759 - val_accuracy: 0.8976
# Epoch 643/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2719 - accuracy: 0.9166 - val_loss: 0.3763 - val_accuracy: 0.8978
# Epoch 644/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2717 - accuracy: 0.9171 - val_loss: 0.3762 - val_accuracy: 0.8978
# Epoch 645/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.2703 - accuracy: 0.9170 - val_loss: 0.3763 - val_accuracy: 0.8977
# Epoch 646/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2691 - accuracy: 0.9180 - val_loss: 0.3760 - val_accuracy: 0.8977
# Epoch 647/1200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.2694 - accuracy: 0.9179 - val_loss: 0.3756 - val_accuracy: 0.8977
# Epoch 648/1200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.2679 - accuracy: 0.9181 - val_loss: 0.3757 - val_accuracy: 0.8977
# Epoch 649/1200
# 58/58 [==============================] - 1s 25ms/step - loss: 0.2676 - accuracy: 0.9187 - val_loss: 0.3761 - val_accuracy: 0.8978
# Epoch 650/1200
# 58/58 [==============================] - 1s 25ms/step - loss: 0.2660 - accuracy: 0.9185 - val_loss: 0.3756 - val_accuracy: 0.8977
# Epoch 651/1200
# 58/58 [==============================] - 2s 26ms/step - loss: 0.2642 - accuracy: 0.9190 - val_loss: 0.3756 - val_accuracy: 0.8978
# Epoch 652/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2638 - accuracy: 0.9190 - val_loss: 0.3762 - val_accuracy: 0.8978
# Epoch 653/1200
# 58/58 [==============================] - 2s 28ms/step - loss: 0.2635 - accuracy: 0.9195 - val_loss: 0.3765 - val_accuracy: 0.8978
# Epoch 654/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2616 - accuracy: 0.9206 - val_loss: 0.3762 - val_accuracy: 0.8978
# Epoch 655/1200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.2603 - accuracy: 0.9209 - val_loss: 0.3761 - val_accuracy: 0.8979
# Epoch 656/1200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.2614 - accuracy: 0.9211 - val_loss: 0.3761 - val_accuracy: 0.8978
# Epoch 657/1200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.2595 - accuracy: 0.9215 - val_loss: 0.3754 - val_accuracy: 0.8978
# Epoch 658/1200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.2575 - accuracy: 0.9215 - val_loss: 0.3752 - val_accuracy: 0.8978
# Epoch 659/1200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.2584 - accuracy: 0.9212 - val_loss: 0.3753 - val_accuracy: 0.8978
# Epoch 660/1200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.2574 - accuracy: 0.9210 - val_loss: 0.3754 - val_accuracy: 0.8977
# Epoch 661/1200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.2564 - accuracy: 0.9219 - val_loss: 0.3754 - val_accuracy: 0.8978
# Epoch 662/1200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.2544 - accuracy: 0.9225 - val_loss: 0.3747 - val_accuracy: 0.8976
# Epoch 663/1200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.2532 - accuracy: 0.9226 - val_loss: 0.3752 - val_accuracy: 0.8976
# Epoch 664/1200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.2546 - accuracy: 0.9220 - val_loss: 0.3753 - val_accuracy: 0.8977
# Epoch 665/1200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.2530 - accuracy: 0.9224 - val_loss: 0.3759 - val_accuracy: 0.8977
# Epoch 666/1200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.2516 - accuracy: 0.9232 - val_loss: 0.3766 - val_accuracy: 0.8978
# Epoch 667/1200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.2500 - accuracy: 0.9244 - val_loss: 0.3768 - val_accuracy: 0.8979
# Epoch 668/1200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.2481 - accuracy: 0.9248 - val_loss: 0.3764 - val_accuracy: 0.8977
# Epoch 669/1200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.2484 - accuracy: 0.9246 - val_loss: 0.3758 - val_accuracy: 0.8977
# Epoch 670/1200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.2477 - accuracy: 0.9242 - val_loss: 0.3758 - val_accuracy: 0.8976
# Epoch 671/1200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.2461 - accuracy: 0.9253 - val_loss: 0.3757 - val_accuracy: 0.8976
# Epoch 672/1200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.2457 - accuracy: 0.9252 - val_loss: 0.3759 - val_accuracy: 0.8976
# Epoch 673/1200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.2443 - accuracy: 0.9261 - val_loss: 0.3762 - val_accuracy: 0.8977
# Epoch 674/1200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.2440 - accuracy: 0.9259 - val_loss: 0.3760 - val_accuracy: 0.8976
# Epoch 675/1200
# 58/58 [==============================] - 1s 21ms/step - loss: 0.2418 - accuracy: 0.9267 - val_loss: 0.3759 - val_accuracy: 0.8976
# Epoch 676/1200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.2400 - accuracy: 0.9272 - val_loss: 0.3760 - val_accuracy: 0.8978
# Epoch 677/1200
# 58/58 [==============================] - 1s 21ms/step - loss: 0.2418 - accuracy: 0.9264 - val_loss: 0.3760 - val_accuracy: 0.8977
# Epoch 678/1200
# 58/58 [==============================] - 1s 21ms/step - loss: 0.2413 - accuracy: 0.9263 - val_loss: 0.3765 - val_accuracy: 0.8978
# Epoch 679/1200
# 58/58 [==============================] - 2s 27ms/step - loss: 0.2393 - accuracy: 0.9273 - val_loss: 0.3762 - val_accuracy: 0.8978
# Epoch 680/1200
# 58/58 [==============================] - 2s 29ms/step - loss: 0.2388 - accuracy: 0.9281 - val_loss: 0.3763 - val_accuracy: 0.8977
# Epoch 681/1200
# 58/58 [==============================] - 1s 25ms/step - loss: 0.2391 - accuracy: 0.9272 - val_loss: 0.3768 - val_accuracy: 0.8977
# Epoch 682/1200
# 58/58 [==============================] - 1s 26ms/step - loss: 0.2375 - accuracy: 0.9282 - val_loss: 0.3764 - val_accuracy: 0.8977

# %%
history = pd.DataFrame(model.history.history)
fig = history.plot()

# %%
print("Classification accuracy:")
classification_dict = dict()
accuracy_list = list() 

for key in x_test_dict:
    x_test_numpy_temp = x_test_dict[key].drop([' TimeStamp (s)', 'Pose'], axis=1).values
    scaler.fit(x_test_numpy_temp)
    classify = model.predict(x_test_numpy_temp)
    classifications = [i.argmax() for i in classify]
    annotated_positions = y_test_dict[key].to_numpy()
    correct_classifications = (classifications == annotated_positions).sum()
    accuracy_list.append(round(correct_classifications/len(classifications)*100,2))
    print(f"{key}: {accuracy_list[-1]}%")
    classification_dict[key] = classifications

print(f"Average accuracy: {round(sum(accuracy_list)/len(accuracy_list),2)}%")
# Out:
# Classification accuracy:
# 001: 80.19%
# 002: 90.23%
# 003: 90.54%
# 004: 89.77%
# 005: 98.66%
# 006: 90.52%
# 007: 84.68%
# 008: 22.07%
# 009: 83.56%
# 010: 72.93%
# Average accuracy: 80.32%

# %%
width=16
height=4*len(x_test_dict)
fig, axes = plt.subplots(len(x_test_dict), 3, figsize=(width, height))
for i, key in enumerate(x_test_dict):
    cols = [f"{key}: Model classifications", f"{key}: Model heatmap", f"{key}: Annotated classifications", f"{key}: Annotated heatmap"]
    df_predict = pd.DataFrame({' Timestamp (s)': x_test_dict[key][' TimeStamp (s)'],'Pose':classification_dict[key]})
    sns.lineplot(ax=axes[i, 0], data=df_predict,x=' Timestamp (s)',y='Pose')
    sns.heatmap(ax=axes[i, 1], data=confusion_matrix(y_test_dict[key], classification_dict[key]), cmap="YlGnBu", annot=True, fmt="d")
    sns.lineplot(ax=axes[i, 2], data=x_test_dict[key], x=" TimeStamp (s)", y='Pose')
    #sns.heatmap(ax=axes[i, 3], data=confusion_matrix(y_test_dict[key], y_test_dict[key].to_numpy()), cmap="YlGnBu", annot=True, fmt="d")
    for ax, col in zip(axes[i], cols): ax.set_title(col)
fig.tight_layout()

plt.show()

# %%
fig.savefig("ANN_3_sensorer_3_heatmap_and_line.png")

# %%
model.save("ANN_3_sensorer_3.h5")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=59d486bc-e14d-4632-9064-12272fc72d11' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
