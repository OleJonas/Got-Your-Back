# %%
import sys; sys.path.insert(0, '..')
import os
import time
import pandas as pd
import numpy as np
import seaborn as sns
import keras
from matplotlib import pyplot as plt
from tabulate import tabulate
from dataclasses import dataclass
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.utils import to_categorical
from keras.optimizers import RMSprop, Adam
from keras.losses import CategoricalCrossentropy
from keras import activations
from sklearn.metrics import confusion_matrix
from utils.df_utils import df_wrapper
from utils.declarations import training_files, testing_files, POSE_MAP

# %%
AMOUNT_OF_SENSORS = 1
VALIDATION_TESTSET = "004"

# %%
x_train_arr = []
for key in training_files:
    elem = df_wrapper(training_files[key].csv_file)
    elem.concat_sensor_data(AMOUNT_OF_SENSORS)
    elem.align_poses(training_files[key].annot_file, POSE_MAP)
    x_train_arr.append(elem)

x_train = pd.concat([x.df.drop([' TimeStamp (s)', 'Pose'],axis=1) for x in x_train_arr])
y_train = pd.concat([x.df['Pose'] for x in x_train_arr])

# %%
x_test_dict = dict()
y_test_dict = dict()
for key in testing_files:
    elem = df_wrapper(testing_files[key].csv_file)
    elem.concat_sensor_data(AMOUNT_OF_SENSORS)
    elem.align_poses(testing_files[key].annot_file, POSE_MAP)
    y_test = elem.df["Pose"]
    y_test.index = [i for i in range(len(y_test))]
    x_test_dict[key] = elem.df
    y_test_dict[key] = y_test

x_test = x_test_dict[VALIDATION_TESTSET].drop([' TimeStamp (s)', 'Pose'], axis=1) 
y_test = y_test_dict[VALIDATION_TESTSET]

# %%
# Create numpy arrays
x_train_numpy = x_train.values
x_test_numpy = x_test.values
y_train_numpy = y_train.values
y_test_numpy = y_test.values

# %%
print("TRAINING SHAPES BEFORE 3D RESHAPE")
print("x_train_numpy: ", x_train_numpy.shape)
print("y_train_numpy: ", y_train_numpy.shape)

print("TESTING SHAPES BEFORE 3D RESHAPE")
print("x_test_numpy: ", x_test_numpy.shape)
print("y_test_numpy: ", y_test_numpy.shape)
# Out:
# TRAINING SHAPES BEFORE 3D RESHAPE
# x_train_numpy:  (468584, 13)
# y_train_numpy:  (468584,)
# TESTING SHAPES BEFORE 3D RESHAPE
# x_test_numpy:  (8367, 13)
# y_test_numpy:  (8367,)

# %%
from scipy import stats

NUM_TIMESTAMPS = 100

def create_3d_array(array):

    arr_3d = []
    temp_2d = []
    for i in range(1,len(array)):
        temp_2d.append(array[i])
        if i % NUM_TIMESTAMPS == 0:
            arr_3d.append(temp_2d)
            temp_2d = []
    
    return arr_3d

def create_2d_y_array(array):
    arr_2d_y_train = []
    temp_y_train = []
    mode_arr = []

    for i in range(1,len(array)):
        #temp_2d.append(array[0])
        temp_y_train.append(array[i])
        if i % NUM_TIMESTAMPS == 0:
            mode_arr.append(temp_y_train)

            temp_y_train = []
            #temp_2d = []

    y_train_to_be_encoded = []

    for i in range(len(mode_arr)):
        mode = stats.mode(mode_arr[i])
        y_train_to_be_encoded.append(mode.mode[0])

    #ONE HOT ENCODING
    encoding = []
    for value in y_train_to_be_encoded:
        vector = [0 for _ in range(9)]
        vector[value] = 1
        encoding.append(vector)
    
    return np.array(encoding)

# %%
x_train_3d = np.array(create_3d_array(x_train_numpy))
y_train_2d = np.array(create_2d_y_array(y_train_numpy))
x_test_3d = np.array(create_3d_array(x_test_numpy))
y_test_2d = np.array(create_2d_y_array(y_test_numpy))

# %%
print("TRAINING DATA AFTER 3D RESHAPE")
print("x_train_3d: ", np.shape(x_train_3d))
print("y_train_2d: ", np.shape(y_train_2d))

print("\nTESTING DATA AFTER 3D RESHAPE")
print("x_test_3d: ", np.shape(x_test_3d))
print("x_test_2d: ", np.shape(y_test_2d))
# Out:
# TRAINING DATA AFTER 3D RESHAPE
# x_train_3d:  (4685, 100, 13)
# y_train_2d:  (4685, 9)
#
# TESTING DATA AFTER 3D RESHAPE
# x_test_3d:  (83, 100, 13)
# x_test_2d:  (83, 9)

# %%
OPTIM = Adam(learning_rate=0.0001)
# OPTIM = RMSprop(learning_rate=LR)

# %%
callbacks = [
    keras.callbacks.CSVLogger("LSTM_1_sensor_3.csv", separator=",", append=False),
    #keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)
]

# %%
model = Sequential()
model.add(LSTM(64, activation='sigmoid', input_shape=[x_train_3d.shape[1], x_train_3d.shape[2]]))
#model.add(LSTM(64, activation='sigmoid', return_sequences=True, input_shape=[x_train_3d.shape[1], x_train_3d.shape[2]]))
#model.add(LSTM(64, activation='sigmoid', input_shape=[x_train_3d.shape[1], x_train_3d.shape[2]]))
model.add(Dense(64, activation='relu'))
model.add(Dropout(rate=0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(rate=0.2))
# model.add(Dense(16, activation='relu'))
# model.add(Dropout(rate=0.2))
# model.add(Dense(16, activation='relu'))
# model.add(Dropout(rate=0.2))
model.add(Dense(12, activation='relu'))
model.add(Dropout(rate=0.2))
# model.add(LSTM(9, activation='sigmoid', input_shape=[x_train_3d.shape[1], x_train_3d.shape[2]]))
# model.add(Dropout(rate=0.2))
# model.add(Dense(9, activation='relu'))
# model.add(Dropout(rate=0.2))
model.add(Dense(9, activation='softmax'))

model.compile(optimizer=OPTIM, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %%
model.fit(x=x_train_3d, y=y_train_2d, batch_size=200, epochs=150, validation_data=(x_test_3d, y_test_2d), callbacks=callbacks)
# Out:
# ========================] - 2s 94ms/step - loss: 2.1878 - accuracy: 0.1294 - val_loss: 2.1935 - val_accuracy: 0.1084
# Epoch 13/150
# 24/24 [==============================] - 2s 93ms/step - loss: 2.1833 - accuracy: 0.1423 - val_loss: 2.1920 - val_accuracy: 0.1205
# Epoch 14/150
# 24/24 [==============================] - 2s 93ms/step - loss: 2.1832 - accuracy: 0.1460 - val_loss: 2.1918 - val_accuracy: 0.1205
# Epoch 15/150
# 24/24 [==============================] - 2s 92ms/step - loss: 2.1737 - accuracy: 0.1541 - val_loss: 2.1901 - val_accuracy: 0.1687
# Epoch 16/150
# 24/24 [==============================] - 2s 100ms/step - loss: 2.1718 - accuracy: 0.1625 - val_loss: 2.1883 - val_accuracy: 0.1687
# Epoch 17/150
# 24/24 [==============================] - 3s 132ms/step - loss: 2.1651 - accuracy: 0.1739 - val_loss: 2.1887 - val_accuracy: 0.1325
# Epoch 18/150
# 24/24 [==============================] - 2s 100ms/step - loss: 2.1559 - accuracy: 0.1903 - val_loss: 2.1827 - val_accuracy: 0.2289
# Epoch 19/150
# 24/24 [==============================] - 3s 110ms/step - loss: 2.1473 - accuracy: 0.1758 - val_loss: 2.1771 - val_accuracy: 0.2530
# Epoch 20/150
# 24/24 [==============================] - 2s 95ms/step - loss: 2.1459 - accuracy: 0.1723 - val_loss: 2.1708 - val_accuracy: 0.1687
# Epoch 21/150
# 24/24 [==============================] - 2s 92ms/step - loss: 2.1323 - accuracy: 0.1920 - val_loss: 2.1634 - val_accuracy: 0.0843
# Epoch 22/150
# 24/24 [==============================] - 2s 100ms/step - loss: 2.1111 - accuracy: 0.2151 - val_loss: 2.1510 - val_accuracy: 0.0843
# Epoch 23/150
# 24/24 [==============================] - 2s 100ms/step - loss: 2.1045 - accuracy: 0.2006 - val_loss: 2.1353 - val_accuracy: 0.0964
# Epoch 24/150
# 24/24 [==============================] - 2s 104ms/step - loss: 2.0827 - accuracy: 0.2093 - val_loss: 2.1221 - val_accuracy: 0.1566
# Epoch 25/150
# 24/24 [==============================] - 3s 116ms/step - loss: 2.0584 - accuracy: 0.2297 - val_loss: 2.1050 - val_accuracy: 0.1566
# Epoch 26/150
# 24/24 [==============================] - 3s 108ms/step - loss: 2.0490 - accuracy: 0.2257 - val_loss: 2.0943 - val_accuracy: 0.1566
# Epoch 27/150
# 24/24 [==============================] - 3s 114ms/step - loss: 2.0121 - accuracy: 0.2434 - val_loss: 2.0617 - val_accuracy: 0.1566
# Epoch 28/150
# 24/24 [==============================] - 3s 109ms/step - loss: 1.9881 - accuracy: 0.2457 - val_loss: 2.0437 - val_accuracy: 0.1566
# Epoch 29/150
# 24/24 [==============================] - 2s 98ms/step - loss: 1.9624 - accuracy: 0.2519 - val_loss: 2.0112 - val_accuracy: 0.1928
# Epoch 30/150
# 24/24 [==============================] - 2s 104ms/step - loss: 1.9478 - accuracy: 0.2538 - val_loss: 1.9813 - val_accuracy: 0.1446
# Epoch 31/150
# 24/24 [==============================] - 2s 102ms/step - loss: 1.9119 - accuracy: 0.2730 - val_loss: 1.9668 - val_accuracy: 0.1687
# Epoch 32/150
# 24/24 [==============================] - 2s 101ms/step - loss: 1.8783 - accuracy: 0.2732 - val_loss: 1.9239 - val_accuracy: 0.2289
# Epoch 33/150
# 24/24 [==============================] - 2s 101ms/step - loss: 1.8591 - accuracy: 0.2696 - val_loss: 1.8972 - val_accuracy: 0.2651
# Epoch 34/150
# 24/24 [==============================] - 2s 98ms/step - loss: 1.8356 - accuracy: 0.2813 - val_loss: 1.8646 - val_accuracy: 0.3133
# Epoch 35/150
# 24/24 [==============================] - 2s 102ms/step - loss: 1.8086 - accuracy: 0.2854 - val_loss: 1.8557 - val_accuracy: 0.2530
# Epoch 36/150
# 24/24 [==============================] - 2s 100ms/step - loss: 1.7794 - accuracy: 0.3017 - val_loss: 1.8532 - val_accuracy: 0.2651
# Epoch 37/150
# 24/24 [==============================] - 2s 98ms/step - loss: 1.7599 - accuracy: 0.3048 - val_loss: 1.8033 - val_accuracy: 0.2771
# Epoch 38/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.7368 - accuracy: 0.3103 - val_loss: 1.8002 - val_accuracy: 0.2289
# Epoch 39/150
# 24/24 [==============================] - 2s 100ms/step - loss: 1.7176 - accuracy: 0.3260 - val_loss: 1.7901 - val_accuracy: 0.2289
# Epoch 40/150
# 24/24 [==============================] - 3s 111ms/step - loss: 1.7151 - accuracy: 0.3252 - val_loss: 1.7514 - val_accuracy: 0.1928
# Epoch 41/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.6733 - accuracy: 0.3363 - val_loss: 1.7438 - val_accuracy: 0.1807
# Epoch 42/150
# 24/24 [==============================] - 2s 101ms/step - loss: 1.6570 - accuracy: 0.3433 - val_loss: 1.7314 - val_accuracy: 0.1928
# Epoch 43/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.6448 - accuracy: 0.3400 - val_loss: 1.7098 - val_accuracy: 0.1928
# Epoch 44/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.6312 - accuracy: 0.3348 - val_loss: 1.6946 - val_accuracy: 0.2651
# Epoch 45/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.5970 - accuracy: 0.3654 - val_loss: 1.6653 - val_accuracy: 0.2530
# Epoch 46/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.5695 - accuracy: 0.3730 - val_loss: 1.6594 - val_accuracy: 0.3012
# Epoch 47/150
# 24/24 [==============================] - 2s 100ms/step - loss: 1.5487 - accuracy: 0.3798 - val_loss: 1.6387 - val_accuracy: 0.3012
# Epoch 48/150
# 24/24 [==============================] - 2s 100ms/step - loss: 1.5285 - accuracy: 0.3970 - val_loss: 1.5896 - val_accuracy: 0.3494
# Epoch 49/150
# 24/24 [==============================] - 2s 98ms/step - loss: 1.5023 - accuracy: 0.4061 - val_loss: 1.5702 - val_accuracy: 0.3976
# Epoch 50/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.4891 - accuracy: 0.4083 - val_loss: 1.5287 - val_accuracy: 0.3373
# Epoch 51/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.4661 - accuracy: 0.4208 - val_loss: 1.5672 - val_accuracy: 0.3976
# Epoch 52/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.4522 - accuracy: 0.4310 - val_loss: 1.4508 - val_accuracy: 0.4699
# Epoch 53/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.4285 - accuracy: 0.4520 - val_loss: 1.4713 - val_accuracy: 0.4578
# Epoch 54/150
# 24/24 [==============================] - 2s 97ms/step - loss: 1.4131 - accuracy: 0.4564 - val_loss: 1.4113 - val_accuracy: 0.6024
# Epoch 55/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.3833 - accuracy: 0.4599 - val_loss: 1.4172 - val_accuracy: 0.5301
# Epoch 56/150
# 24/24 [==============================] - 2s 100ms/step - loss: 1.3814 - accuracy: 0.4712 - val_loss: 1.3706 - val_accuracy: 0.6024
# Epoch 57/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.3354 - accuracy: 0.4850 - val_loss: 1.3587 - val_accuracy: 0.6024
# Epoch 58/150
# 24/24 [==============================] - 2s 100ms/step - loss: 1.3463 - accuracy: 0.4833 - val_loss: 1.3323 - val_accuracy: 0.6024
# Epoch 59/150
# 24/24 [==============================] - 2s 98ms/step - loss: 1.3142 - accuracy: 0.5057 - val_loss: 1.2925 - val_accuracy: 0.6145
# Epoch 60/150
# 24/24 [==============================] - 2s 100ms/step - loss: 1.2846 - accuracy: 0.5049 - val_loss: 1.2799 - val_accuracy: 0.6024
# Epoch 61/150
# 24/24 [==============================] - 2s 100ms/step - loss: 1.2726 - accuracy: 0.5210 - val_loss: 1.2208 - val_accuracy: 0.6627
# Epoch 62/150
# 24/24 [==============================] - 2s 98ms/step - loss: 1.2643 - accuracy: 0.5064 - val_loss: 1.2130 - val_accuracy: 0.6386
# Epoch 63/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.2533 - accuracy: 0.5222 - val_loss: 1.2119 - val_accuracy: 0.6024
# Epoch 64/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.2361 - accuracy: 0.5270 - val_loss: 1.1683 - val_accuracy: 0.6747
# Epoch 65/150
# 24/24 [==============================] - 2s 103ms/step - loss: 1.2113 - accuracy: 0.5244 - val_loss: 1.1299 - val_accuracy: 0.6265
# Epoch 66/150
# 24/24 [==============================] - 3s 116ms/step - loss: 1.1813 - accuracy: 0.5584 - val_loss: 1.1242 - val_accuracy: 0.6386
# Epoch 67/150
# 24/24 [==============================] - 3s 116ms/step - loss: 1.1684 - accuracy: 0.5645 - val_loss: 1.1074 - val_accuracy: 0.6386
# Epoch 68/150
# 24/24 [==============================] - 3s 123ms/step - loss: 1.1730 - accuracy: 0.5565 - val_loss: 1.1096 - val_accuracy: 0.6506
# Epoch 69/150
# 24/24 [==============================] - 3s 144ms/step - loss: 1.1809 - accuracy: 0.5421 - val_loss: 1.0197 - val_accuracy: 0.6988
# Epoch 70/150
# 24/24 [==============================] - 3s 128ms/step - loss: 1.1356 - accuracy: 0.5716 - val_loss: 1.0466 - val_accuracy: 0.6747
# Epoch 71/150
# 24/24 [==============================] - 3s 106ms/step - loss: 1.1236 - accuracy: 0.5732 - val_loss: 1.0039 - val_accuracy: 0.7108
# Epoch 72/150
# 24/24 [==============================] - 2s 103ms/step - loss: 1.1357 - accuracy: 0.5806 - val_loss: 0.9972 - val_accuracy: 0.7470
# Epoch 73/150
# 24/24 [==============================] - 2s 104ms/step - loss: 1.1193 - accuracy: 0.5760 - val_loss: 0.9794 - val_accuracy: 0.6988
# Epoch 74/150
# 24/24 [==============================] - 3s 106ms/step - loss: 1.0987 - accuracy: 0.5913 - val_loss: 0.9684 - val_accuracy: 0.6867
# Epoch 75/150
# 24/24 [==============================] - 3s 112ms/step - loss: 1.0844 - accuracy: 0.5922 - val_loss: 0.9871 - val_accuracy: 0.6506
# Epoch 76/150
# 24/24 [==============================] - 3s 118ms/step - loss: 1.0847 - accuracy: 0.5910 - val_loss: 0.9131 - val_accuracy: 0.7349
# Epoch 77/150
# 24/24 [==============================] - 4s 179ms/step - loss: 1.0758 - accuracy: 0.5926 - val_loss: 0.9317 - val_accuracy: 0.7229
# Epoch 78/150
# 24/24 [==============================] - 4s 185ms/step - loss: 1.0508 - accuracy: 0.6108 - val_loss: 0.9007 - val_accuracy: 0.7229
# Epoch 79/150
# 24/24 [==============================] - 3s 132ms/step - loss: 1.0715 - accuracy: 0.5928 - val_loss: 0.9043 - val_accuracy: 0.6747
# Epoch 80/150
# 24/24 [==============================] - 3s 108ms/step - loss: 1.0762 - accuracy: 0.6048 - val_loss: 0.9003 - val_accuracy: 0.7108
# Epoch 81/150
# 24/24 [==============================] - 2s 100ms/step - loss: 1.0397 - accuracy: 0.6168 - val_loss: 0.9149 - val_accuracy: 0.6506
# Epoch 82/150
# 24/24 [==============================] - 2s 101ms/step - loss: 1.0418 - accuracy: 0.6094 - val_loss: 0.8634 - val_accuracy: 0.7470
# Epoch 83/150
# 24/24 [==============================] - 2s 100ms/step - loss: 1.0386 - accuracy: 0.6114 - val_loss: 0.8952 - val_accuracy: 0.7108
# Epoch 84/150
# 24/24 [==============================] - 3s 106ms/step - loss: 1.0287 - accuracy: 0.6168 - val_loss: 0.9059 - val_accuracy: 0.6506
# Epoch 85/150
# 24/24 [==============================] - 2s 101ms/step - loss: 1.0036 - accuracy: 0.6130 - val_loss: 0.8388 - val_accuracy: 0.7470
# Epoch 86/150
# 24/24 [==============================] - 3s 103ms/step - loss: 1.0137 - accuracy: 0.6092 - val_loss: 0.8212 - val_accuracy: 0.7470
# Epoch 87/150
# 24/24 [==============================] - 2s 101ms/step - loss: 1.0384 - accuracy: 0.6187 - val_loss: 0.8236 - val_accuracy: 0.7470
# Epoch 88/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.0130 - accuracy: 0.6157 - val_loss: 0.8739 - val_accuracy: 0.6867
# Epoch 89/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.9992 - accuracy: 0.6197 - val_loss: 0.8276 - val_accuracy: 0.7470
# Epoch 90/150
# 24/24 [==============================] - 2s 99ms/step - loss: 1.0128 - accuracy: 0.6120 - val_loss: 0.8127 - val_accuracy: 0.7470
# Epoch 91/150
# 24/24 [==============================] - 3s 104ms/step - loss: 0.9808 - accuracy: 0.6375 - val_loss: 0.8328 - val_accuracy: 0.7349
# Epoch 92/150
# 24/24 [==============================] - 3s 105ms/step - loss: 0.9791 - accuracy: 0.6408 - val_loss: 0.8043 - val_accuracy: 0.7470
# Epoch 93/150
# 24/24 [==============================] - 2s 102ms/step - loss: 0.9907 - accuracy: 0.6294 - val_loss: 0.8341 - val_accuracy: 0.7108
# Epoch 94/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.9689 - accuracy: 0.6398 - val_loss: 0.7756 - val_accuracy: 0.7470
# Epoch 95/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.9732 - accuracy: 0.6448 - val_loss: 0.7776 - val_accuracy: 0.7470
# Epoch 96/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.9774 - accuracy: 0.6438 - val_loss: 0.8165 - val_accuracy: 0.7470
# Epoch 97/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.9585 - accuracy: 0.6436 - val_loss: 0.8308 - val_accuracy: 0.7229
# Epoch 98/150
# 24/24 [==============================] - 2s 98ms/step - loss: 0.9411 - accuracy: 0.6547 - val_loss: 0.7796 - val_accuracy: 0.6988
# Epoch 99/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.9547 - accuracy: 0.6474 - val_loss: 0.7944 - val_accuracy: 0.7470
# Epoch 100/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.9558 - accuracy: 0.6364 - val_loss: 0.7622 - val_accuracy: 0.7470
# Epoch 101/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.9264 - accuracy: 0.6659 - val_loss: 0.7883 - val_accuracy: 0.7470
# Epoch 102/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.9499 - accuracy: 0.6424 - val_loss: 0.7844 - val_accuracy: 0.6988
# Epoch 103/150
# 24/24 [==============================] - 2s 102ms/step - loss: 0.9297 - accuracy: 0.6617 - val_loss: 0.7427 - val_accuracy: 0.8072
# Epoch 104/150
# 24/24 [==============================] - 3s 116ms/step - loss: 0.9266 - accuracy: 0.6549 - val_loss: 0.7611 - val_accuracy: 0.7470
# Epoch 105/150
# 24/24 [==============================] - 3s 135ms/step - loss: 0.9138 - accuracy: 0.6625 - val_loss: 0.7548 - val_accuracy: 0.7108
# Epoch 106/150
# 24/24 [==============================] - 3s 109ms/step - loss: 0.9060 - accuracy: 0.6685 - val_loss: 0.7659 - val_accuracy: 0.6988
# Epoch 107/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.9565 - accuracy: 0.6437 - val_loss: 0.7515 - val_accuracy: 0.7470
# Epoch 108/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.9140 - accuracy: 0.6632 - val_loss: 0.7737 - val_accuracy: 0.6988
# Epoch 109/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.8993 - accuracy: 0.6644 - val_loss: 0.7516 - val_accuracy: 0.7470
# Epoch 110/150
# 24/24 [==============================] - 3s 108ms/step - loss: 0.8974 - accuracy: 0.6552 - val_loss: 0.7566 - val_accuracy: 0.7349
# Epoch 111/150
# 24/24 [==============================] - 2s 103ms/step - loss: 0.9200 - accuracy: 0.6647 - val_loss: 0.7609 - val_accuracy: 0.7349
# Epoch 112/150
# 24/24 [==============================] - 3s 108ms/step - loss: 0.9118 - accuracy: 0.6558 - val_loss: 0.7226 - val_accuracy: 0.8434
# Epoch 113/150
# 24/24 [==============================] - 3s 111ms/step - loss: 0.9027 - accuracy: 0.6737 - val_loss: 0.7158 - val_accuracy: 0.8434
# Epoch 114/150
# 24/24 [==============================] - 3s 105ms/step - loss: 0.9149 - accuracy: 0.6495 - val_loss: 0.7445 - val_accuracy: 0.6867
# Epoch 115/150
# 24/24 [==============================] - 2s 100ms/step - loss: 0.9094 - accuracy: 0.6590 - val_loss: 0.7360 - val_accuracy: 0.7470
# Epoch 116/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.8521 - accuracy: 0.6912 - val_loss: 0.7670 - val_accuracy: 0.7108
# Epoch 117/150
# 24/24 [==============================] - 2s 102ms/step - loss: 0.8971 - accuracy: 0.6698 - val_loss: 0.7240 - val_accuracy: 0.8434
# Epoch 118/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.8475 - accuracy: 0.6812 - val_loss: 0.7026 - val_accuracy: 0.8313
# Epoch 119/150
# 24/24 [==============================] - 2s 103ms/step - loss: 0.8913 - accuracy: 0.6686 - val_loss: 0.7196 - val_accuracy: 0.7711
# Epoch 120/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.8597 - accuracy: 0.6859 - val_loss: 0.7188 - val_accuracy: 0.7711
# Epoch 121/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.8567 - accuracy: 0.6844 - val_loss: 0.7270 - val_accuracy: 0.6988
# Epoch 122/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.8454 - accuracy: 0.6930 - val_loss: 0.7197 - val_accuracy: 0.7711
# Epoch 123/150
# 24/24 [==============================] - 2s 102ms/step - loss: 0.8521 - accuracy: 0.6866 - val_loss: 0.7137 - val_accuracy: 0.7349
# Epoch 124/150
# 24/24 [==============================] - 2s 102ms/step - loss: 0.8410 - accuracy: 0.6861 - val_loss: 0.6957 - val_accuracy: 0.8193
# Epoch 125/150
# 24/24 [==============================] - 2s 103ms/step - loss: 0.8624 - accuracy: 0.6743 - val_loss: 0.7153 - val_accuracy: 0.8072
# Epoch 126/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.8423 - accuracy: 0.6913 - val_loss: 0.6953 - val_accuracy: 0.8313
# Epoch 127/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.8459 - accuracy: 0.6917 - val_loss: 0.7008 - val_accuracy: 0.8554
# Epoch 128/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.8302 - accuracy: 0.6941 - val_loss: 0.7183 - val_accuracy: 0.8193
# Epoch 129/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.8612 - accuracy: 0.6881 - val_loss: 0.7047 - val_accuracy: 0.7711
# Epoch 130/150
# 24/24 [==============================] - 3s 109ms/step - loss: 0.8121 - accuracy: 0.6981 - val_loss: 0.6996 - val_accuracy: 0.8313
# Epoch 131/150
# 24/24 [==============================] - 3s 107ms/step - loss: 0.8405 - accuracy: 0.6986 - val_loss: 0.6866 - val_accuracy: 0.8434
# Epoch 132/150
# 24/24 [==============================] - 2s 99ms/step - loss: 0.8253 - accuracy: 0.6987 - val_loss: 0.7321 - val_accuracy: 0.7470
# Epoch 133/150
# 24/24 [==============================] - 2s 102ms/step - loss: 0.8349 - accuracy: 0.6888 - val_loss: 0.7712 - val_accuracy: 0.6988
# Epoch 134/150
# 24/24 [==============================] - 2s 102ms/step - loss: 0.8562 - accuracy: 0.6816 - val_loss: 0.6958 - val_accuracy: 0.8434
# Epoch 135/150
# 24/24 [==============================] - 2s 104ms/step - loss: 0.7990 - accuracy: 0.7070 - val_loss: 0.6770 - val_accuracy: 0.8313
# Epoch 136/150
# 24/24 [==============================] - 3s 109ms/step - loss: 0.8306 - accuracy: 0.6915 - val_loss: 0.6811 - val_accuracy: 0.8434
# Epoch 137/150
# 24/24 [==============================] - 3s 105ms/step - loss: 0.8241 - accuracy: 0.6954 - val_loss: 0.6843 - val_accuracy: 0.8193
# Epoch 138/150
# 24/24 [==============================] - 3s 105ms/step - loss: 0.7859 - accuracy: 0.7142 - val_loss: 0.7306 - val_accuracy: 0.7470
# Epoch 139/150
# 24/24 [==============================] - 2s 103ms/step - loss: 0.8269 - accuracy: 0.6902 - val_loss: 0.7055 - val_accuracy: 0.8193
# Epoch 140/150
# 24/24 [==============================] - 3s 106ms/step - loss: 0.7977 - accuracy: 0.7066 - val_loss: 0.6919 - val_accuracy: 0.8554
# Epoch 141/150
# 24/24 [==============================] - 3s 111ms/step - loss: 0.7809 - accuracy: 0.7256 - val_loss: 0.7056 - val_accuracy: 0.8434
# Epoch 142/150
# 24/24 [==============================] - 3s 105ms/step - loss: 0.8403 - accuracy: 0.6820 - val_loss: 0.7195 - val_accuracy: 0.6747
# Epoch 143/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.8096 - accuracy: 0.6981 - val_loss: 0.6965 - val_accuracy: 0.7831
# Epoch 144/150
# 24/24 [==============================] - 2s 98ms/step - loss: 0.8258 - accuracy: 0.6898 - val_loss: 0.7071 - val_accuracy: 0.7349
# Epoch 145/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.7809 - accuracy: 0.7189 - val_loss: 0.6814 - val_accuracy: 0.8675
# Epoch 146/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.7953 - accuracy: 0.7119 - val_loss: 0.6899 - val_accuracy: 0.8072
# Epoch 147/150
# 24/24 [==============================] - 2s 102ms/step - loss: 0.7787 - accuracy: 0.7219 - val_loss: 0.6951 - val_accuracy: 0.8193
# Epoch 148/150
# 24/24 [==============================] - 2s 101ms/step - loss: 0.7613 - accuracy: 0.7227 - val_loss: 0.6940 - val_accuracy: 0.8675
# Epoch 149/150
# 24/24 [==============================] - 2s 103ms/step - loss: 0.7798 - accuracy: 0.7255 - val_loss: 0.6655 - val_accuracy: 0.8554
# Epoch 150/150
# 24/24 [==============================] - 2s 102ms/step - loss: 0.7778 - accuracy: 0.7222 - val_loss: 0.7445 - val_accuracy: 0.8072

# %%
history = pd.DataFrame(model.history.history)
history.plot()
# Out:
# <AxesSubplot:>

# %%
print("Classification accuracy:")
classification_dict = dict()
accuracy_list = list() 


for key in x_test_dict:
    x_test_numpy_temp = x_test_dict[key].drop([' TimeStamp (s)', 'Pose'], axis=1).values
    x_test_numpy_temp_3d = np.array(create_3d_array(x_test_numpy_temp))
    y_test_temp = np.array(create_2d_y_array(y_test_dict[key]))
    print(key)
    classify = model.evaluate(x_test_numpy_temp_3d, y_test_temp)
    # classifications = [i.argmax() for i in classify]
    # annotated_positions = y_test_dict[key].to_numpy()
    # correct_classifications = (classifications == annotated_positions).sum()
    # accuracy_list.append(round(correct_classifications/len(classifications)*100,2))
    # print(f"{key}: {accuracy_list[-1]}%")
    # classification_dict[key] = classifications

# print(f"Average accuracy: {round(sum(accuracy_list)/len(accuracy_list),2)}%")
# Out:
# Classification accuracy:
# 001
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6717 - accuracy: 0.7317
# 002
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6653 - accuracy: 0.7949
# 003
# 4/4 [==============================] - 0s 9ms/step - loss: 1.7172 - accuracy: 0.5500
# 004
# 3/3 [==============================] - 0s 11ms/step - loss: 0.7445 - accuracy: 0.8072
# 005
# 3/3 [==============================] - 0s 11ms/step - loss: 0.7000 - accuracy: 0.7444
# 006
# 3/3 [==============================] - 0s 9ms/step - loss: 0.8392 - accuracy: 0.6438
# 007
# 1/1 [==============================] - 0s 25ms/step - loss: 1.0791 - accuracy: 0.7143
# 008
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7812 - accuracy: 0.7000
# 009
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4519 - accuracy: 0.9125
# 010
# 3/3 [==============================] - 0s 9ms/step - loss: 2.0956 - accuracy: 0.4337

# %%
model.save("LSTM_1_sensor_3.h5")
