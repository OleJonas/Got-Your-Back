# %%
import sys; sys.path.insert(0, '..')
import os
import time
import pandas as pd
import keras
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from tabulate import tabulate
from dataclasses import dataclass
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.utils import to_categorical
from keras.optimizers import RMSprop, Adam
from keras.losses import CategoricalCrossentropy
from keras import activations
from sklearn.metrics import confusion_matrix
from utils.df_utils import df_wrapper
from utils.declarations import training_files, testing_files, POSE_MAP

# %%
AMOUNT_OF_SENSORS = 1
VALIDATION_TESTSET = "004"

# %%
x_train_arr = []
for key in training_files:
    elem = df_wrapper(training_files[key].csv_file)
    elem.concat_sensor_data(AMOUNT_OF_SENSORS)
    elem.align_poses(training_files[key].annot_file, POSE_MAP)
    x_train_arr.append(elem)
    
x_train = pd.concat([x.df.drop([' TimeStamp (s)', 'Pose'],axis=1) for x in x_train_arr])
y_train = pd.concat([x.df['Pose'] for x in x_train_arr])

# %%
x_test_dict = dict()
y_test_dict = dict()
for key in testing_files:
    elem = df_wrapper(testing_files[key].csv_file)
    elem.concat_sensor_data(AMOUNT_OF_SENSORS)
    elem.align_poses(testing_files[key].annot_file, POSE_MAP)
    y_test = elem.df["Pose"]
    y_test.index = [i for i in range(len(y_test))]
    x_test_dict[key] = elem.df
    y_test_dict[key] = y_test
    print(key)

x_test = x_test_dict[VALIDATION_TESTSET].drop([' TimeStamp (s)', 'Pose'], axis=1) 
y_test = y_test_dict[VALIDATION_TESTSET]
# Out:
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010

# %%
# Create numpy arrays
x_train_numpy = x_train.values
x_test_numpy = x_test.values
y_train_numpy = y_train.values
y_test_numpy = y_test.values

# Hot encode categories into numbers
y_train = to_categorical(y_train_numpy,9)
y_test = to_categorical(y_test_numpy,9)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-6e4b6a1fb918> in <module>
#       2 x_train_numpy = x_train.values
#       3 x_test_numpy = x_test.values
# ----> 4 y_train_numpy = y_train.values
#       5 y_test_numpy = y_test.values
#       6
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
print("TRAINING SHAPES")
print("x_train_numpy: ", x_train_numpy.shape)
print("y_train_numpy: ", y_train_numpy.shape)

print("TESTING SHAPES")
print("x_test_numpy: ", x_test_numpy.shape)
print("y_test_numpy: ", y_test_numpy.shape)
# Out:
# TRAINING SHAPES
# x_train_numpy:  (468584, 13)
# y_train_numpy:  (468584,)
# TESTING SHAPES
# x_test_numpy:  (8367, 13)
# y_test_numpy:  (8367,)

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
scaler.fit(x_train_numpy)
scaler.fit(x_test_numpy)
# Out:
# RobustScaler()

# %%
OPTIM = Adam(learning_rate=0.00001)
# OPTIM = RMSprop(learning_rate=LR)

# %%
callbacks = [
    keras.callbacks.CSVLogger("ANN_1_sensor_3.csv", separator=",", append=False),
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=30)
]

# %%
model = Sequential()
# model.add(Dense(64, activation='relu'))
# model.add(Dropout(rate=0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(rate=0.3))
model.add(Dense(32, activation='relu'))
model.add(Dropout(rate=0.3))
model.add(Dense(12, activation='relu'))
model.add(Dropout(rate=0.3))
model.add(Dense(9, activation='softmax'))

model.compile(optimizer=OPTIM, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %%
model.fit(x=x_train_numpy, y=y_train, batch_size=8192, epochs=2000, validation_data=(x_test_numpy, y_test), callbacks=callbacks)
# Out:
# och 1044/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6446 - accuracy: 0.7697 - val_loss: 0.6270 - val_accuracy: 0.7741
# Epoch 1045/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6472 - accuracy: 0.7697 - val_loss: 0.6265 - val_accuracy: 0.7751
# Epoch 1046/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6454 - accuracy: 0.7707 - val_loss: 0.6261 - val_accuracy: 0.7763
# Epoch 1047/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6445 - accuracy: 0.7708 - val_loss: 0.6263 - val_accuracy: 0.7727
# Epoch 1048/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6447 - accuracy: 0.7700 - val_loss: 0.6257 - val_accuracy: 0.7742
# Epoch 1049/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6470 - accuracy: 0.7693 - val_loss: 0.6249 - val_accuracy: 0.7757
# Epoch 1050/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6444 - accuracy: 0.7717 - val_loss: 0.6245 - val_accuracy: 0.7753
# Epoch 1051/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6448 - accuracy: 0.7716 - val_loss: 0.6250 - val_accuracy: 0.7704
# Epoch 1052/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6408 - accuracy: 0.7731 - val_loss: 0.6254 - val_accuracy: 0.7685
# Epoch 1053/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6407 - accuracy: 0.7730 - val_loss: 0.6251 - val_accuracy: 0.7690
# Epoch 1054/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6446 - accuracy: 0.7714 - val_loss: 0.6250 - val_accuracy: 0.7699
# Epoch 1055/2000
# 58/58 [==============================] - 2s 32ms/step - loss: 0.6410 - accuracy: 0.7727 - val_loss: 0.6242 - val_accuracy: 0.7733
# Epoch 1056/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6397 - accuracy: 0.7733 - val_loss: 0.6250 - val_accuracy: 0.7679
# Epoch 1057/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6429 - accuracy: 0.7722 - val_loss: 0.6252 - val_accuracy: 0.7654
# Epoch 1058/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6397 - accuracy: 0.7736 - val_loss: 0.6250 - val_accuracy: 0.7629
# Epoch 1059/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6406 - accuracy: 0.7721 - val_loss: 0.6245 - val_accuracy: 0.7631
# Epoch 1060/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6397 - accuracy: 0.7728 - val_loss: 0.6239 - val_accuracy: 0.7662
# Epoch 1061/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6402 - accuracy: 0.7731 - val_loss: 0.6238 - val_accuracy: 0.7665
# Epoch 1062/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6411 - accuracy: 0.7732 - val_loss: 0.6245 - val_accuracy: 0.7594
# Epoch 1063/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6386 - accuracy: 0.7731 - val_loss: 0.6243 - val_accuracy: 0.7588
# Epoch 1064/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6378 - accuracy: 0.7741 - val_loss: 0.6240 - val_accuracy: 0.7595
# Epoch 1065/2000
# 58/58 [==============================] - 2s 32ms/step - loss: 0.6375 - accuracy: 0.7734 - val_loss: 0.6239 - val_accuracy: 0.7600
# Epoch 1066/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6369 - accuracy: 0.7742 - val_loss: 0.6236 - val_accuracy: 0.7605
# Epoch 1067/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6381 - accuracy: 0.7727 - val_loss: 0.6238 - val_accuracy: 0.7588
# Epoch 1068/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6352 - accuracy: 0.7753 - val_loss: 0.6228 - val_accuracy: 0.7605
# Epoch 1069/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6328 - accuracy: 0.7744 - val_loss: 0.6224 - val_accuracy: 0.7631
# Epoch 1070/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6339 - accuracy: 0.7759 - val_loss: 0.6225 - val_accuracy: 0.7614
# Epoch 1071/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6349 - accuracy: 0.7743 - val_loss: 0.6227 - val_accuracy: 0.7583
# Epoch 1072/2000
# 58/58 [==============================] - 2s 32ms/step - loss: 0.6334 - accuracy: 0.7753 - val_loss: 0.6220 - val_accuracy: 0.7607
# Epoch 1073/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6348 - accuracy: 0.7748 - val_loss: 0.6213 - val_accuracy: 0.7642
# Epoch 1074/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6322 - accuracy: 0.7759 - val_loss: 0.6210 - val_accuracy: 0.7649
# Epoch 1075/2000
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6314 - accuracy: 0.7777 - val_loss: 0.6209 - val_accuracy: 0.7618
# Epoch 1076/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6316 - accuracy: 0.7764 - val_loss: 0.6204 - val_accuracy: 0.7628
# Epoch 1077/2000
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6334 - accuracy: 0.7758 - val_loss: 0.6206 - val_accuracy: 0.7632
# Epoch 1078/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6316 - accuracy: 0.7769 - val_loss: 0.6212 - val_accuracy: 0.7598
# Epoch 1079/2000
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6320 - accuracy: 0.7766 - val_loss: 0.6209 - val_accuracy: 0.7604
# Epoch 1080/2000
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6311 - accuracy: 0.7765 - val_loss: 0.6205 - val_accuracy: 0.7597
# Epoch 1081/2000
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6296 - accuracy: 0.7779 - val_loss: 0.6209 - val_accuracy: 0.7546
# Epoch 1082/2000
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6293 - accuracy: 0.7782 - val_loss: 0.6214 - val_accuracy: 0.7515
# Epoch 1083/2000
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6286 - accuracy: 0.7770 - val_loss: 0.6216 - val_accuracy: 0.7489
# Epoch 1084/2000
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6279 - accuracy: 0.7781 - val_loss: 0.6212 - val_accuracy: 0.7487
# Epoch 1085/2000
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6274 - accuracy: 0.7774 - val_loss: 0.6211 - val_accuracy: 0.7459
# Epoch 1086/2000
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6254 - accuracy: 0.7792 - val_loss: 0.6206 - val_accuracy: 0.7459
# Epoch 1087/2000
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6272 - accuracy: 0.7780 - val_loss: 0.6202 - val_accuracy: 0.7478
# Epoch 1088/2000
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6291 - accuracy: 0.7781 - val_loss: 0.6197 - val_accuracy: 0.7499
# Epoch 1089/2000
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6267 - accuracy: 0.7785 - val_loss: 0.6202 - val_accuracy: 0.7435
# Epoch 1090/2000
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6229 - accuracy: 0.7808 - val_loss: 0.6201 - val_accuracy: 0.7446
# Epoch 1091/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6249 - accuracy: 0.7782 - val_loss: 0.6192 - val_accuracy: 0.7484
# Epoch 1092/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6238 - accuracy: 0.7795 - val_loss: 0.6190 - val_accuracy: 0.7469
# Epoch 1093/2000
# 58/58 [==============================] - 2s 32ms/step - loss: 0.6250 - accuracy: 0.7795 - val_loss: 0.6187 - val_accuracy: 0.7461
# Epoch 1094/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6253 - accuracy: 0.7788 - val_loss: 0.6186 - val_accuracy: 0.7475
# Epoch 1095/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6227 - accuracy: 0.7817 - val_loss: 0.6185 - val_accuracy: 0.7461
# Epoch 1096/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6205 - accuracy: 0.7806 - val_loss: 0.6190 - val_accuracy: 0.7410
# Epoch 1097/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6243 - accuracy: 0.7801 - val_loss: 0.6189 - val_accuracy: 0.7404
# Epoch 1098/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6235 - accuracy: 0.7800 - val_loss: 0.6182 - val_accuracy: 0.7452
# Epoch 1099/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6203 - accuracy: 0.7808 - val_loss: 0.6182 - val_accuracy: 0.7432
# Epoch 1100/2000
# 58/58 [==============================] - 2s 32ms/step - loss: 0.6222 - accuracy: 0.7805 - val_loss: 0.6177 - val_accuracy: 0.7461
# Epoch 1101/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6205 - accuracy: 0.7805 - val_loss: 0.6179 - val_accuracy: 0.7436
# Epoch 1102/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6219 - accuracy: 0.7796 - val_loss: 0.6171 - val_accuracy: 0.7481
# Epoch 1103/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6235 - accuracy: 0.7797 - val_loss: 0.6176 - val_accuracy: 0.7445
# Epoch 1104/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6204 - accuracy: 0.7810 - val_loss: 0.6172 - val_accuracy: 0.7435
# Epoch 1105/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6212 - accuracy: 0.7805 - val_loss: 0.6178 - val_accuracy: 0.7402
# Epoch 1106/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6166 - accuracy: 0.7822 - val_loss: 0.6168 - val_accuracy: 0.7429
# Epoch 1107/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6156 - accuracy: 0.7820 - val_loss: 0.6164 - val_accuracy: 0.7472
# Epoch 1108/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6199 - accuracy: 0.7810 - val_loss: 0.6162 - val_accuracy: 0.7442
# Epoch 1109/2000
# 58/58 [==============================] - 2s 32ms/step - loss: 0.6187 - accuracy: 0.7814 - val_loss: 0.6154 - val_accuracy: 0.7500
# Epoch 1110/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6182 - accuracy: 0.7819 - val_loss: 0.6159 - val_accuracy: 0.7455
# Epoch 1111/2000
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6144 - accuracy: 0.7828 - val_loss: 0.6164 - val_accuracy: 0.7418
# Epoch 1112/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6159 - accuracy: 0.7830 - val_loss: 0.6167 - val_accuracy: 0.7387
# Epoch 1113/2000
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6158 - accuracy: 0.7829 - val_loss: 0.6170 - val_accuracy: 0.7357
# Epoch 1114/2000
# 58/58 [==============================] - 3s 47ms/step - loss: 0.6147 - accuracy: 0.7838 - val_loss: 0.6177 - val_accuracy: 0.7319
# Epoch 1115/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6136 - accuracy: 0.7844 - val_loss: 0.6166 - val_accuracy: 0.7375
# Epoch 1116/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6153 - accuracy: 0.7832 - val_loss: 0.6166 - val_accuracy: 0.7373
# Epoch 1117/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6146 - accuracy: 0.7824 - val_loss: 0.6164 - val_accuracy: 0.7368
# Epoch 1118/2000
# 58/58 [==============================] - 1s 18ms/step - loss: 0.6122 - accuracy: 0.7837 - val_loss: 0.6154 - val_accuracy: 0.7409
# Epoch 1119/2000
# 58/58 [==============================] - 1s 18ms/step - loss: 0.6137 - accuracy: 0.7841 - val_loss: 0.6150 - val_accuracy: 0.7436
# Epoch 1120/2000
# 58/58 [==============================] - 1s 15ms/step - loss: 0.6135 - accuracy: 0.7844 - val_loss: 0.6151 - val_accuracy: 0.7427
# Epoch 1121/2000
# 58/58 [==============================] - 1s 14ms/step - loss: 0.6140 - accuracy: 0.7828 - val_loss: 0.6144 - val_accuracy: 0.7441
# Epoch 1122/2000
# 58/58 [==============================] - 1s 20ms/step - loss: 0.6113 - accuracy: 0.7842 - val_loss: 0.6150 - val_accuracy: 0.7396
# Epoch 1123/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6095 - accuracy: 0.7862 - val_loss: 0.6140 - val_accuracy: 0.7430
# Epoch 1124/2000
# 58/58 [==============================] - 1s 15ms/step - loss: 0.6134 - accuracy: 0.7834 - val_loss: 0.6139 - val_accuracy: 0.7429
# Epoch 1125/2000
# 58/58 [==============================] - 1s 14ms/step - loss: 0.6107 - accuracy: 0.7842 - val_loss: 0.6145 - val_accuracy: 0.7384
# Epoch 1126/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6113 - accuracy: 0.7842 - val_loss: 0.6150 - val_accuracy: 0.7360
# Epoch 1127/2000
# 58/58 [==============================] - 1s 19ms/step - loss: 0.6080 - accuracy: 0.7863 - val_loss: 0.6148 - val_accuracy: 0.7363
# Epoch 1128/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6072 - accuracy: 0.7869 - val_loss: 0.6137 - val_accuracy: 0.7395
# Epoch 1129/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6081 - accuracy: 0.7871 - val_loss: 0.6148 - val_accuracy: 0.7341
# Epoch 1130/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6095 - accuracy: 0.7853 - val_loss: 0.6142 - val_accuracy: 0.7372
# Epoch 1131/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6074 - accuracy: 0.7868 - val_loss: 0.6140 - val_accuracy: 0.7383
# Epoch 1132/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6095 - accuracy: 0.7855 - val_loss: 0.6140 - val_accuracy: 0.7380
# Epoch 1133/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6039 - accuracy: 0.7873 - val_loss: 0.6140 - val_accuracy: 0.7361
# Epoch 1134/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6065 - accuracy: 0.7872 - val_loss: 0.6139 - val_accuracy: 0.7356
# Epoch 1135/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6074 - accuracy: 0.7866 - val_loss: 0.6141 - val_accuracy: 0.7335
# Epoch 1136/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6053 - accuracy: 0.7866 - val_loss: 0.6144 - val_accuracy: 0.7334
# Epoch 1137/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6073 - accuracy: 0.7868 - val_loss: 0.6139 - val_accuracy: 0.7338
# Epoch 1138/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6040 - accuracy: 0.7875 - val_loss: 0.6131 - val_accuracy: 0.7386
# Epoch 1139/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6056 - accuracy: 0.7886 - val_loss: 0.6141 - val_accuracy: 0.7329
# Epoch 1140/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6059 - accuracy: 0.7878 - val_loss: 0.6145 - val_accuracy: 0.7319
# Epoch 1141/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6051 - accuracy: 0.7879 - val_loss: 0.6141 - val_accuracy: 0.7322
# Epoch 1142/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6010 - accuracy: 0.7891 - val_loss: 0.6146 - val_accuracy: 0.7298
# Epoch 1143/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6035 - accuracy: 0.7882 - val_loss: 0.6147 - val_accuracy: 0.7289
# Epoch 1144/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6039 - accuracy: 0.7883 - val_loss: 0.6142 - val_accuracy: 0.7311
# Epoch 1145/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6033 - accuracy: 0.7885 - val_loss: 0.6136 - val_accuracy: 0.7341
# Epoch 1146/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6025 - accuracy: 0.7881 - val_loss: 0.6145 - val_accuracy: 0.7311
# Epoch 1147/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6012 - accuracy: 0.7889 - val_loss: 0.6144 - val_accuracy: 0.7308
# Epoch 1148/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6016 - accuracy: 0.7880 - val_loss: 0.6141 - val_accuracy: 0.7295
# Epoch 1149/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6028 - accuracy: 0.7873 - val_loss: 0.6133 - val_accuracy: 0.7320
# Epoch 1150/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6027 - accuracy: 0.7881 - val_loss: 0.6123 - val_accuracy: 0.7342
# Epoch 1151/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6015 - accuracy: 0.7877 - val_loss: 0.6130 - val_accuracy: 0.7311
# Epoch 1152/2000
# 58/58 [==============================] - 1s 19ms/step - loss: 0.5998 - accuracy: 0.7893 - val_loss: 0.6135 - val_accuracy: 0.7319
# Epoch 1153/2000
# 58/58 [==============================] - 1s 20ms/step - loss: 0.5994 - accuracy: 0.7898 - val_loss: 0.6129 - val_accuracy: 0.7322
# Epoch 1154/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5993 - accuracy: 0.7894 - val_loss: 0.6143 - val_accuracy: 0.7282
# Epoch 1155/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5964 - accuracy: 0.7901 - val_loss: 0.6140 - val_accuracy: 0.7287
# Epoch 1156/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5957 - accuracy: 0.7917 - val_loss: 0.6135 - val_accuracy: 0.7302
# Epoch 1157/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5973 - accuracy: 0.7904 - val_loss: 0.6142 - val_accuracy: 0.7267
# Epoch 1158/2000
# 58/58 [==============================] - 1s 16ms/step - loss: 0.5998 - accuracy: 0.7889 - val_loss: 0.6147 - val_accuracy: 0.7251
# Epoch 1159/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.6008 - accuracy: 0.7889 - val_loss: 0.6149 - val_accuracy: 0.7224
# Epoch 1160/2000
# 58/58 [==============================] - 1s 18ms/step - loss: 0.5975 - accuracy: 0.7909 - val_loss: 0.6137 - val_accuracy: 0.7244
# Epoch 1161/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5952 - accuracy: 0.7916 - val_loss: 0.6142 - val_accuracy: 0.7240
# Epoch 1162/2000
# 58/58 [==============================] - 1s 18ms/step - loss: 0.5972 - accuracy: 0.7903 - val_loss: 0.6140 - val_accuracy: 0.7246
# Epoch 1163/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5962 - accuracy: 0.7907 - val_loss: 0.6144 - val_accuracy: 0.7233
# Epoch 1164/2000
# 58/58 [==============================] - 1s 18ms/step - loss: 0.5955 - accuracy: 0.7920 - val_loss: 0.6138 - val_accuracy: 0.7240
# Epoch 1165/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5961 - accuracy: 0.7910 - val_loss: 0.6136 - val_accuracy: 0.7270
# Epoch 1166/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5953 - accuracy: 0.7910 - val_loss: 0.6138 - val_accuracy: 0.7265
# Epoch 1167/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5911 - accuracy: 0.7919 - val_loss: 0.6140 - val_accuracy: 0.7232
# Epoch 1168/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5959 - accuracy: 0.7911 - val_loss: 0.6136 - val_accuracy: 0.7246
# Epoch 1169/2000
# 58/58 [==============================] - 1s 18ms/step - loss: 0.5951 - accuracy: 0.7912 - val_loss: 0.6134 - val_accuracy: 0.7226
# Epoch 1170/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5932 - accuracy: 0.7907 - val_loss: 0.6135 - val_accuracy: 0.7227
# Epoch 1171/2000
# 58/58 [==============================] - 1s 18ms/step - loss: 0.5963 - accuracy: 0.7899 - val_loss: 0.6126 - val_accuracy: 0.7255
# Epoch 1172/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5928 - accuracy: 0.7924 - val_loss: 0.6129 - val_accuracy: 0.7245
# Epoch 1173/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5926 - accuracy: 0.7929 - val_loss: 0.6133 - val_accuracy: 0.7225
# Epoch 1174/2000
# 58/58 [==============================] - 1s 18ms/step - loss: 0.5933 - accuracy: 0.7914 - val_loss: 0.6136 - val_accuracy: 0.7215
# Epoch 1175/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5905 - accuracy: 0.7926 - val_loss: 0.6131 - val_accuracy: 0.7234
# Epoch 1176/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5914 - accuracy: 0.7921 - val_loss: 0.6135 - val_accuracy: 0.7215
# Epoch 1177/2000
# 58/58 [==============================] - 1s 18ms/step - loss: 0.5915 - accuracy: 0.7915 - val_loss: 0.6137 - val_accuracy: 0.7212
# Epoch 1178/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5898 - accuracy: 0.7922 - val_loss: 0.6137 - val_accuracy: 0.7216
# Epoch 1179/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5930 - accuracy: 0.7917 - val_loss: 0.6130 - val_accuracy: 0.7238
# Epoch 1180/2000
# 58/58 [==============================] - 1s 17ms/step - loss: 0.5895 - accuracy: 0.7931 - val_loss: 0.6131 - val_accuracy: 0.7213

# %%
history = pd.DataFrame(model.history.history)
history.plot()
# Out:
# <AxesSubplot:>

# %%
# df = pd.read_csv("ANN_1_sensor_1.csv")
# df["kjoring"] = 1
# df.to_csv("ANN_1_sensor_1.csv", index=False)

# %%
print("Classification accuracy:")
classification_dict = dict()
accuracy_list = list() 

for key in x_test_dict:
    x_test_numpy_temp = x_test_dict[key].drop([' TimeStamp (s)', 'Pose'], axis=1).values
    scaler.fit(x_test_numpy_temp)
    classify = model.predict(x_test_numpy_temp)
    classifications = [i.argmax() for i in classify]
    annotated_positions = y_test_dict[key].to_numpy()
    correct_classifications = (classifications == annotated_positions).sum()
    accuracy_list.append(round(correct_classifications/len(classifications)*100,2))
    print(f"{key}: {accuracy_list[-1]}%")
    classification_dict[key] = classifications

print(f"Average accuracy: {round(sum(accuracy_list)/len(accuracy_list),2)}%")
# Out:
# Classification accuracy:
# 001: 84.8%
# 002: 64.27%
# 003: 34.7%
# 004: 72.13%
# 005: 76.39%
# 006: 64.85%
# 007: 67.75%
# 008: 93.02%
# 009: 90.41%
# 010: 44.78%
# Average accuracy: 69.31%

# %%
width=16
height=4*len(x_test_dict)
fig, axes = plt.subplots(len(x_test_dict), 3, figsize=(width, height))
for i, key in enumerate(x_test_dict):
    cols = [f"{key}: Model classifications", f"{key}: Model heatmap", f"{key}: Annotated classifications", f"{key}: Annotated heatmap"]
    df_predict = pd.DataFrame({' Timestamp (s)': x_test_dict[key][' TimeStamp (s)'],'Pose':classification_dict[key]})
    sns.lineplot(ax=axes[i, 0], data=df_predict,x=' Timestamp (s)',y='Pose')
    sns.heatmap(ax=axes[i, 1], data=confusion_matrix(y_test_dict[key], classification_dict[key]), cmap="YlGnBu", annot=True, fmt="d")
    sns.lineplot(ax=axes[i, 2], data=x_test_dict[key], x=" TimeStamp (s)", y='Pose')
    # sns.heatmap(ax=axes[i, 3], data=confusion_matrix(y_test_dict[key], y_test_dict[key].to_numpy()), cmap="YlGnBu", annot=True, fmt="d")
    for ax, col in zip(axes[i], cols): ax.set_title(col)
fig.tight_layout()

plt.show()

# %%
fig.savefig("ANN_1_sensor_3_heatmap_and_line.png")

# %%
model.save("ANN_1_sensor_3.h5")
